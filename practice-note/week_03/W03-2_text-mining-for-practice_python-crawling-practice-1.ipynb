# %% [markdown]
# # TEXT MINING for PRACTICE
# - 본 자료는 텍스트 마이닝을 활용한 연구 및 강의를 위한 목적으로 제작되었습니다.
# - 본 자료를 강의 목적으로 활용하고자 하시는 경우 꼭 아래 메일주소로 연락주세요.
# - 본 자료에 대한 허가되지 않은 배포를 금지합니다.
# - 강의, 저작권, 출판, 특허, 공동저자에 관련해서는 문의 바랍니다.
# - **Contact : ADMIN(admin@teanaps.com)**
#
# ---

# %% [markdown]
# ## WEEK 03-2. 정적 페이지 수집하기: 실시간 검색어, 영화댓글
# - Python을 활용해 단순한 웹페이지에서 데이터를 크롤링하는 방법에 대해 다룹니다.
#
# ---

# %% [markdown]
# > **\*\*\* 주의사항 \*\*\***
# 본 자료에서 설명하는 웹크롤링하는 방법은 해당 기법에 대한 이해를 돕고자하는 교육의 목적으로 사용되었으며,
# 이를 활용한 대량의 무단 크롤링은 범죄에 해당할 수 있음을 알려드립니다.

# %% [markdown]
# ### 1. 네이버 실시간 검색어 가져오기
#
# ---

# %% [markdown]
# > ####  정적 페이지 크롤링 과정
# > 1. 진짜 URL 찾기
# 2. requests 패키지를 활용해 URL 호출하기
# 3. BeautifulSoup과 HtmlParser 패키지로 HTML 태그 불러오기
# 4. 불러온 페이지에 원하는 내용이 포함되어있는지 PRINT 문으로 확인하기 - 포함되어 있지 않으면 1번부터 다시시작!
# 5. Chrome 브라우저 [메뉴] > [도구 더보기] > [개발자도구] 메뉴를 통해 원하는 내용이 포함된 태그 확인 후 호출
# 6. 가져온 데이터 정리해서 파일에 저장하기

# %%
# Python 코드를 통해 웹페이지에 정보를 요청하기 위해 BeautifulSoup, urllib 패키지를 import 합니다.
from bs4 import BeautifulSoup 
import requests

# %%
# 1. 진짜 URL 찾기
# 네이버 실시간 검색어는 네이버 데이터랩 급상승검색어 페이지에 존재합니다.
URL = "https://datalab.naver.com/keyword/realtimeList.naver?"
URL += "age=10s"                           # 연령
URL += "&datetime=2020-09-21T14%3A00%3A00" # 집계주기
URL += "&entertainment=-2"                 # 엔터
URL += "&groupingLevel=0"                  # 이슈별 묶어보기
URL += "&marketing=-2"                     # 이벤트/할인
URL += "&news=-2"                          # 시사
URL += "&sports=-2"                        # 스포츠

# %%
# 2. requests 패키지를 활용해 URL 호출하기
# 네이버 메인페이지 URL을 호출합니다.

#response = requests.get(URL)

headers = {
    "Referer": "https://datalab.naver.com/keyword/realtimeList.naver?age=20s&datetime=2020-09-19T14%3A00%3A00",
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36",
}
response = requests.get(URL, headers=headers)

# %%
#response.text

# %%
# 3. BeautifulSoup과 HtmlParser 패키지로 HTML 태그 불러오기
soup = BeautifulSoup(response.text, "html.parser")

# %%
# 4. 불러온 페이지에 원하는 내용이 포함되어있는지 PRINT 문으로 확인하기
# PRINT 문을 활용해 불러온 웹페이지 내용을 출력합니다.

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1200" name="viewport"/>
# <title>급상승검색어 : 네이버 데이터랩</title>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/css/datalab.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/css/graph.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/android_legacy_xxxhpdi_192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/android_legacy_xxhpdi_144x144.png" rel="icon" sizes="144x144"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/android_legacy_xhdpi_96x96.png" rel="icon" sizes="96x96"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/android_legacy_hdpi_72X72.png" rel="icon" sizes="72x72"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/iOS_iPhone@3x_180X180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/iOS_iPadPro@2x_167X167.png" rel="apple-touch-icon-precomposed" sizes="167x167"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/iOS_iPad@2x_152X152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://ssl.pstatic.net/static.datalab/202004030222/img/favicon/iOS_iPhone@2x_120X120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <meta content="네이버 데이터랩 : 급상승 검색어" property="og:title">
# <meta content="https://datalab.naver.com/realtimeList.naver" property="og:url">
# <meta content="https://ssl.pstatic.net/static.datalab/img2019/datalab_og_244x244.jpg" property="og:image">
# <meta content="검색 횟수가 급상승한 검색어의 순위를 다양한 옵션을 통해 자세히 제공합니다." property="og:description"/>
# <meta content="검색 횟수가 급상승한 검색어의 순위를 다양한 옵션을 통해 자세히 제공합니다." name="description"/>
# </meta></meta></meta></head>
# <!--[if lte IE 9]>
# <body class="pop_opened">
# <![endif]-->
# <?if !IE?>
# <body>
# <?endif?>
# <div class="wrap" id="wrap">
# <div class="header" id="header">
# <div class="inner">
# <div class="srch_wrap">
# <a class="logo_area" href="https://www.naver.com" target="_blank">
# <span class="sp_header_logo"><span class="blind">NAVER</span></span>
# </a>
# <h1 class="sta_area">
# <a class="sp_sta" href="/"><span class="blind">DataLab</span></a>
# </h1>
# </div>
# <div class="gnb_wrap">
# <div id="gnb"></div>
# </div>
# </div>
# <div class="lnb" id="lnb">
# <div class="lnb_innner">
# <ul class="lnb_list">
# <li class="list _home ">
# <a class="list_area" href="/">
# <span class="sp_lnb_list nav1">
# <span class="blind">데이터랩 홈</span>
# </span>
# </a>
# </li>
# <li class="list _keyword active">
# <a class="list_area" href="/keyword/realtimeList.naver">
# <span class="sp_lnb_list nav2">
# <span class="blind">급상승검색어</span>
# </span>
# </a>
# </li>
# <li class="list _keyword ">
# <a class="list_area" href="/keyword/trendSearch.naver">
# <span class="sp_lnb_list nav3">
# <span class="blind">검색어트렌드</span>
# </span>
# </a>
# </li>
# <li class="list _shopping ">
# <a class="list_area" href="/shoppingInsight/sCategory.naver">
# <span class="sp_lnb_list nav4">
# <span class="blind">쇼핑인사이트</span>
# </span>
# </a>
# </li>
# <li class="list _local ">
# <a class="list_area" href="/local/trend.naver">
# <span class="sp_lnb_list nav5">
# <span class="blind">지역통계</span>
# </span>
# </a>
# </li>
# <li class="list _commentStat ">
# <a class="list_area" href="/commentStat/news.naver">
# <span class="sp_lnb_list nav6">
# <span class="blind">뉴스댓글통계</span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container" id="container" role="main">
# <div class="content" id="content">
# <div class="section_keyword">
# <div class="com_title title_keyword">
# <h3 class="title">급상승 검색어</h3>
# <em class="desc">검색 횟수가 급상승한 검색어의 순위를 다양한 옵션을 통해 자세히 제공합니다.</em>
# <!-- [D] 'btn_guide' 클릭시 class="on" 추가해주세요. -->
# <div class="guide_box">
# <button class="btn_guide" type="button"><span class="blind">급상승 검색어 옵션 조절 기능 안내</span></button>
# <div class="tooltip_guide">
# <div class="tooltip_wrap">
# <p class="tooltip_txt">검색어 설정 기능은 검색어가 해당 주제에 어느 정도 관련성이 있는 지를 분석, 측정한 후, 사용자가 선택하는 옵션 단계에 따라 가중치를 가감하여 급상승검색어를 재정렬하는 기능입니다.
#                     관련도의 분석, 측정은 AI 기반 검색어 추천 로직에 의해 이루어지며 일부 검색어는 실제 주제 연관성과 다르게 측정되고 정렬될 수 있습니다. </p>
# <a class="btn_detail" href="https://blog.naver.com/naver_diary/221694954271" target="_blank">자세히 보기</a>
# <button class="btn_close" type="button"><span class="blind">안내 문구 닫기</span></button>
# </div>
# </div>
# </div>
# </div>
# <div class="selection_area">
# <div class="selection_header">
# <div class="selection_box">
# <div class="box_wrap">
# <strong class="title_txt">집계 주기</strong>
# <div class="section_serch_area">
# <div class="select_inbo _picker_component" data-datetime="2020-09-21T14:00:00" data-end="2020-09-21T21:46:00" data-start="2020-01-16T06:00:00">
# <div class="date_indo" href="#">
# <a class="date_btn _prev_day" href="#"><span class="blind">이전 날짜로 가기</span></a>
# <a class="date_btn next _next_day btn_off" href="#"><span class="blind">다음 날짜로 가기</span></a>
# <a class="date_box _date_trigger" href="#">
# <span class="date_txt _title_ymd">2020.09.21. <em>(월)</em></span>
# <span class="date_ico"><span class="blind">달력</span></span>
# </a>
# <!-- [D] 캘린더 활성화 display:block 추가 부탁 드립니다 -->
# <div class="calendar" id="_calendar">
# <div class="layer_area _date_wrapper" style="display:none">
# <div class="calendar_area _leftMonth">
# <div class="calendar_head">
# <strong class="calendar-title _title_ym">2017.02.</strong>
# <!--[D] 링크 비활성화 a 링크에 class="off" 추가 -->
# <a class="calendar-btn-prev-mon _prev" data-date="" href="#"><span class="btn_prev">이전달</span></a>
# <a class="calendar-btn-next-mon _next" data-date="" href="#"><span class="btn_next">다음달</span></a>
# </div>
# <div class="calendar_body _calendar"></div>
# </div>
# <div class="sub_area">
# <a class="btn_today _today" href="#">오늘</a>
# <a class="btn_check _confirm" href="#">확인</a>
# </div>
# <div class="calendar_popup">
# <div class="ly_cont">
# <p class="cont_txt">2020.01.16. 이전 데이터는<br/>아래의 버튼을 눌러 확인해주세요.</p>
# </div>
# <div class="ly_btn_bottom">
# <a class="btn_data" href="realtimeList.naver?datetime=2020-01-16T05:59:00" target="_blank"><span class="data_txt">2020.01.16. 이전 데이터 조회</span></a>
# </div>
# <a class="btn_popup_close" href="#none"><span class="blind">팝업닫기</span></a>
# </div>
# </div>
# </div>
# </div><!-- [D] 비활성화시 class="time_indo" 에 v2를 입력해주세요 -->
# <div class="time_indo" href="#">
# <a class="time_btn _prev_tick" href="#"><span class="blind">이전 시간으로 가기</span></a>
# <a class="time_btn next _next_tick btn_off" href="#"><span class="blind">다음 시간으로 가기</span></a>
# <a class="time_box _time_trigger" href="#">
# <span class="time_txt _title_hms">14:00</span>
# <span class="time_ico"><span class="blind">시간</span></span>
# </a>
# <!-- [D] 시간탬 활성화 display:block 추가 부탁 드립니다. -->
# <div class="layer_time _time_wrapper time_no_second" id="u.c.layer.time" style="display:none">
# <div class="hour">
# <!--[AU] data-max 에 입력가능 최대 숫자 설정-->
# <!-- [AU] scrollbar-box 클래스 위치 변경 -->
# <input class="time_input _tinput _hour" data-max="23" maxlength="2" type="text" value="14"/><span class="blind">시</span>
# <div class="time_scroll scrollbar-box _tlist _hour" id="scrollbox" style="overflow: hidden;">
# <div class="scrollbar-content" style="top: 0px; height: auto;">
# <ul class="lst_time">
# <li class="selected _item"><a href="#">00</a></li>
# <li class="_item"><a href="#">01</a></li>
# <li class="_item"><a href="#">02</a></li>
# <li class="_item"><a href="#">03</a></li>
# <li class="_item"><a href="#">04</a></li>
# <li class="_item"><a href="#">05</a></li>
# <li class="_item"><a href="#">06</a></li>
# <li class="_item"><a href="#">07</a></li>
# <li class="_item"><a href="#">08</a></li>
# <li class="_item"><a href="#">09</a></li>
# <li class="_item"><a href="#">10</a></li>
# <li class="_item"><a href="#">11</a></li>
# <li class="_item"><a href="#">12</a></li>
# <li class="_item"><a href="#">13</a></li>
# <li class="_item"><a href="#">14</a></li>
# <li class="_item"><a href="#">15</a></li>
# <li class="_item"><a href="#">16</a></li>
# <li class="_item"><a href="#">17</a></li>
# <li class="_item"><a href="#">18</a></li>
# <li class="_item"><a href="#">19</a></li>
# <li class="_item"><a href="#">20</a></li>
# <li class="_item"><a href="#">21</a></li>
# <li class="_item"><a href="#">22</a></li>
# <li class="_item"><a href="#">23</a></li>
# </ul>
# </div>
# <div class="iScrollVerticalScrollbar scrollbar-show">
# <div class="scrollbar-button-up rollover"></div>
# <div class="scrollbar-track rollover" style="height: 202px;">
# <div class="iScrollIndicator S21614895 rollover S84675399" style="top: 0px; height: 61px;"></div>
# </div>
# <div class="scrollbar-button-down rollover"></div>
# </div>
# </div>
# </div>
# <div class="hour_minute">:</div>
# <div class="minute">
# <!--[AU] data-max 에 입력가능 최대 숫자 설정-->
# <input class="time_input _tinput _minute" data-max="59" maxlength="2" type="text" value="00"/><span class="blind">분</span>
# <div class="time_scroll scrollbar-box _tlist _minute" id="scrollbox2" style="overflow: hidden;">
# <div class="scrollbar-content" style="top: 0px; height: auto;">
# <ul class="lst_time">
# <li class="selected _item"><a href="#">00</a></li>
# <li class="_item"><a href="#">01</a></li>
# <li class="_item"><a href="#">02</a></li>
# <li class="_item"><a href="#">03</a></li>
# <li class="_item"><a href="#">04</a></li>
# <li class="_item"><a href="#">05</a></li>
# <li class="_item"><a href="#">06</a></li>
# <li class="_item"><a href="#">07</a></li>
# <li class="_item"><a href="#">08</a></li>
# <li class="_item"><a href="#">09</a></li>
# <li class="_item"><a href="#">10</a></li>
# <li class="_item"><a href="#">11</a></li>
# <li class="_item"><a href="#">12</a></li>
# <li class="_item"><a href="#">13</a></li>
# <li class="_item"><a href="#">14</a></li>
# <li class="_item"><a href="#">15</a></li>
# <li class="_item"><a href="#">16</a></li>
# <li class="_item"><a href="#">17</a></li>
# <li class="_item"><a href="#">18</a></li>
# <li class="_item"><a href="#">19</a></li>
# <li class="_item"><a href="#">20</a></li>
# <li class="_item"><a href="#">21</a></li>
# <li class="_item"><a href="#">22</a></li>
# <li class="_item"><a href="#">23</a></li>
# <li class="_item"><a href="#">24</a></li>
# <li class="_item"><a href="#">25</a></li>
# <li class="_item"><a href="#">26</a></li>
# <li class="_item"><a href="#">27</a></li>
# <li class="_item"><a href="#">28</a></li>
# <li class="_item"><a href="#">29</a></li>
# <li class="_item"><a href="#">30</a></li>
# <li class="_item"><a href="#">31</a></li>
# <li class="_item"><a href="#">32</a></li>
# <li class="_item"><a href="#">33</a></li>
# <li class="_item"><a href="#">34</a></li>
# <li class="_item"><a href="#">35</a></li>
# <li class="_item"><a href="#">36</a></li>
# <li class="_item"><a href="#">37</a></li>
# <li class="_item"><a href="#">38</a></li>
# <li class="_item"><a href="#">39</a></li>
# <li class="_item"><a href="#">40</a></li>
# <li class="_item"><a href="#">41</a></li>
# <li class="_item"><a href="#">42</a></li>
# <li class="_item"><a href="#">43</a></li>
# <li class="_item"><a href="#">44</a></li>
# <li class="_item"><a href="#">45</a></li>
# <li class="_item"><a href="#">46</a></li>
# <li class="_item"><a href="#">47</a></li>
# <li class="_item"><a href="#">48</a></li>
# <li class="_item"><a href="#">49</a></li>
# <li class="_item"><a href="#">50</a></li>
# <li class="_item"><a href="#">51</a></li>
# <li class="_item"><a href="#">52</a></li>
# <li class="_item"><a href="#">53</a></li>
# <li class="_item"><a href="#">54</a></li>
# <li class="_item"><a href="#">55</a></li>
# <li class="_item"><a href="#">56</a></li>
# <li class="_item"><a href="#">57</a></li>
# <li class="_item"><a href="#">58</a></li>
# <li class="_item"><a href="#">59</a></li>
# </ul>
# </div>
# <div class="iScrollVerticalScrollbar scrollbar-show">
# <div class="scrollbar-button-up rollover"></div>
# <div class="scrollbar-track rollover" style="height: 202px;">
# <div class="iScrollIndicator S6808276 rollover S39500592" style="top: 0px; height: 25px;"></div>
# </div>
# <div class="scrollbar-button-down rollover"></div>
# </div>
# </div>
# </div>
# <div class="hour_minute v2">:</div>
# <div class="sec">
# <!--[AU] data-max 에 입력가능 최대 숫자 설정-->
# <input class="time_input _tinput _second" data-max="30" maxlength="2" type="text" value="00"/><span class="blind">초</span>
# <div class="time_scroll v2 scrollbar-box _tlist _second" id="scrollbox3" style="overflow: hidden;">
# <div class="scrollbar-box" style="width: 62px; height: 202px;">
# <ul class="lst_time">
# <li class="selected _item" data-value="00"><a href="#">00</a></li>
# <li class="_item" data-value="30"><a href="#">30</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="sub_area v2">
# <a class="btn_today _now" href="#">지금</a>
# <a class="btn_check _confirm" href="#">확인</a>
# </div>
# </div>
# </div> </div>
# </div>
# </div>
# </div>
# <div class="selection_box _age_filter" data-age="10s">
# <div class="box_wrap">
# <strong class="title_txt">연령</strong>
# <div class="section_keyword_detail">
# <div class="graph_tab_box">
# <ul class="graph_tab_list">
# <!-- [D] 선택된 li에 class="on" 추가 -->
# <li class="on">
# <a href="#none">10대</a>
# </li>
# <li class="">
# <a href="#none">20대</a>
# </li>
# <li class="">
# <a href="#none">30대</a>
# </li>
# <li class="">
# <a href="#none">40대</a>
# </li>
# <li class="">
# <a href="#none">50대 -</a>
# </li>
# <li class="">
# <a href="#none">전체</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- 상세옵션 및 대표검색어,유사검색어 ranking -->
# <div class="selection_content">
# <div class="field_option">
# <div class="option_box">
# <strong class="box_title">상세 옵션</strong>
# <div class="box_content">
# <!-- filter -->
# <div class="various_filter_area">
# <ul class="filter_list">
# <!--[D] 필터 주제에 따라 클래스 추가해주세요.
#                                 이슈별 묶어보기: default
#                                 이벤트・할인: item_event
#                                 시사: item_actualities
#                                 엔터: item_enter
#                                 스포츠: item_sports
#                                 -->
# <li class="filter_item _opt_filter ">
# <strong class="item_title">이슈별 묶어보기</strong>
# <div class="item_graph_wrap">
# <div class="item_graph" role="radiogroup">
# <!--[D] 활성화/비활성화시 aria-checked=true/false로 변경해주세요.-->
# <a aria-checked="true" aria-label="0%" class="level" href="#" role="radio">
# <span class="blind">1단계</span>
# </a>
# <a aria-checked="false" aria-label="25%" class="level" href="#" role="radio">
# <span class="blind">2단계</span>
# </a>
# <a aria-checked="false" aria-label="50%" class="level" href="#" role="radio">
# <span class="blind">3단계</span>
# </a>
# <a aria-checked="false" aria-label="75%" class="level" href="#" role="radio">
# <span class="blind">4단계</span>
# </a>
# <a aria-checked="false" aria-label="100%" class="level" href="#" role="radio">
# <span class="blind">5단계</span>
# </a>
# <div class="item_fill" style="width: 0%;"></div>
# </div>
# </div>
# </li>
# <li class="filter_item _opt_filter item_event">
# <strong class="item_title">이벤트・할인</strong>
# <div class="item_graph_wrap">
# <div class="item_graph" role="radiogroup">
# <!--[D] 활성화/비활성화시 aria-checked=true/false로 변경해주세요.-->
# <a aria-checked="true" aria-label="0%" class="level" href="#" role="radio">
# <span class="blind">1단계</span>
# </a>
# <a aria-checked="false" aria-label="25%" class="level" href="#" role="radio">
# <span class="blind">2단계</span>
# </a>
# <a aria-checked="false" aria-label="50%" class="level" href="#" role="radio">
# <span class="blind">3단계</span>
# </a>
# <a aria-checked="false" aria-label="75%" class="level" href="#" role="radio">
# <span class="blind">4단계</span>
# </a>
# <a aria-checked="false" aria-label="100%" class="level" href="#" role="radio">
# <span class="blind">5단계</span>
# </a>
# <div class="item_fill" style="width: 0%;"></div>
# </div>
# </div>
# </li>
# <li class="filter_item _opt_filter item_actualities">
# <strong class="item_title">시사</strong>
# <div class="item_graph_wrap">
# <div class="item_graph" role="radiogroup">
# <!--[D] 활성화/비활성화시 aria-checked=true/false로 변경해주세요.-->
# <a aria-checked="true" aria-label="0%" class="level" href="#" role="radio">
# <span class="blind">1단계</span>
# </a>
# <a aria-checked="false" aria-label="25%" class="level" href="#" role="radio">
# <span class="blind">2단계</span>
# </a>
# <a aria-checked="false" aria-label="50%" class="level" href="#" role="radio">
# <span class="blind">3단계</span>
# </a>
# <a aria-checked="false" aria-label="75%" class="level" href="#" role="radio">
# <span class="blind">4단계</span>
# </a>
# <a aria-checked="false" aria-label="100%" class="level" href="#" role="radio">
# <span class="blind">5단계</span>
# </a>
# <div class="item_fill" style="width: 0%;"></div>
# </div>
# </div>
# </li>
# <li class="filter_item _opt_filter item_enter">
# <strong class="item_title">엔터</strong>
# <div class="item_graph_wrap">
# <div class="item_graph" role="radiogroup">
# <!--[D] 활성화/비활성화시 aria-checked=true/false로 변경해주세요.-->
# <a aria-checked="true" aria-label="0%" class="level" href="#" role="radio">
# <span class="blind">1단계</span>
# </a>
# <a aria-checked="false" aria-label="25%" class="level" href="#" role="radio">
# <span class="blind">2단계</span>
# </a>
# <a aria-checked="false" aria-label="50%" class="level" href="#" role="radio">
# <span class="blind">3단계</span>
# </a>
# <a aria-checked="false" aria-label="75%" class="level" href="#" role="radio">
# <span class="blind">4단계</span>
# </a>
# <a aria-checked="false" aria-label="100%" class="level" href="#" role="radio">
# <span class="blind">5단계</span>
# </a>
# <div class="item_fill" style="width: 0%;"></div>
# </div>
# </div>
# </li>
# <li class="filter_item _opt_filter item_sports">
# <strong class="item_title">스포츠</strong>
# <div class="item_graph_wrap">
# <div class="item_graph" role="radiogroup">
# <!--[D] 활성화/비활성화시 aria-checked=true/false로 변경해주세요.-->
# <a aria-checked="true" aria-label="0%" class="level" href="#" role="radio">
# <span class="blind">1단계</span>
# </a>
# <a aria-checked="false" aria-label="25%" class="level" href="#" role="radio">
# <span class="blind">2단계</span>
# </a>
# <a aria-checked="false" aria-label="50%" class="level" href="#" role="radio">
# <span class="blind">3단계</span>
# </a>
# <a aria-checked="false" aria-label="75%" class="level" href="#" role="radio">
# <span class="blind">4단계</span>
# </a>
# <a aria-checked="false" aria-label="100%" class="level" href="#" role="radio">
# <span class="blind">5단계</span>
# </a>
# <div class="item_fill" style="width: 0%;"></div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="option_box box_bottom">
# <strong class="box_title">과거 데이터 조회하기</strong>
# <div class="box_content">
# <ul class="previous_data">
# <li class="data_item"><a href="realtimeList.naver?datetime=2018-10-10T05:59:30" target="_blank">2017.03.29. ~ 2018.10.10.</a></li>
# <li class="data_item"><a href="realtimeList.naver?datetime=2019-11-28T05:59:00" target="_blank">2018.10.10. ~ 2019.11.28.</a></li>
# <li class="data_item"><a href="realtimeList.naver?datetime=2020-01-16T05:59:00" target="_blank">2019.11.28. ~ 2020.01.16.</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="field_list">
# <div class="ranking_box">
# <div class="list_group">
# <ul class="ranking_list">
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">1</span>
# <span class="item_title_wrap">
# <span class="item_title">어디가</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">2</span>
# <span class="item_title_wrap">
# <span class="item_title">아지땅</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">3</span>
# <span class="item_title_wrap">
# <span class="item_title">유웨이</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">4</span>
# <span class="item_title_wrap">
# <span class="item_title">배경화면</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">5</span>
# <span class="item_title_wrap">
# <span class="item_title">2021 신인드래프트</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">6</span>
# <span class="item_title_wrap">
# <span class="item_title">쇼타로</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">7</span>
# <span class="item_title_wrap">
# <span class="item_title">nct</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">8</span>
# <span class="item_title_wrap">
# <span class="item_title">엔시티</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">9</span>
# <span class="item_title_wrap">
# <span class="item_title">성찬</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">10</span>
# <span class="item_title_wrap">
# <span class="item_title">엔시티 2020</span>
# </span>
# </div>
# </li>
# </ul>
# <ul class="ranking_list">
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">11</span>
# <span class="item_title_wrap">
# <span class="item_title">케이타운포유</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">12</span>
# <span class="item_title_wrap">
# <span class="item_title">대학어디가</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">13</span>
# <span class="item_title_wrap">
# <span class="item_title">유웨이어플라이</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">14</span>
# <span class="item_title_wrap">
# <span class="item_title">동아대 코로나</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">15</span>
# <span class="item_title_wrap">
# <span class="item_title">어쩌다 결혼</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">16</span>
# <span class="item_title_wrap">
# <span class="item_title">엔하이픈</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">17</span>
# <span class="item_title_wrap">
# <span class="item_title">남영신</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">18</span>
# <span class="item_title_wrap">
# <span class="item_title">호서대학교</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">19</span>
# <span class="item_title_wrap">
# <span class="item_title">동국대학교</span>
# </span>
# </div>
# </li>
# <li class="ranking_item">
# <div class="item_box">
# <span class="item_num">20</span>
# <span class="item_title_wrap">
# <span class="item_title">진학사 어플라이</span>
# </span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- //상세옵션 및 대표검색어,유사검색어 ranking -->
# </div>
# </div>
# </div>
# <div class="_data" style="display:none">
# <span class="_subject_server"></span>
# <span class="_keyword_server"></span>
# </div>
# </div>
# <div class="footer" id="footer">
# <div class="footer_inner">
# <div class="footer_info">
# <a href="https://policy.naver.com/rules/service.html" target="_blank">이용약관</a>
# <a href="https://policy.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a>
# <a href="https://policy.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a>
# <a href="https://help.naver.com/support/service/main.nhn?serviceNo=14493" target="_blank">고객센터</a>
# </div>
# <div class="footer_copyright">
# <a class="sp_footer_logo" href="https://www.naver.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em class="copyright">Copyright ©</em>
# <strong><a href="https://www.navercorp.com/ko/index.nhn" target="_blank">NAVER Corp.</a></strong> All Rights Reserved.
#             </div>
# </div>
# </div>
# </div>
# <!--[if lte IE 9]>
# <div class="com_browser_pop" style="display:none">
#     <div class="pop_dimmed"></div>
#     <div class="pop_inner type_browser">
#         <strong class="browser_title">권장 브라우저 안내</strong>
#         <p class="browser_desc">
#             해당 사이트에 최적화된 브라우저는 Internet Explorer10 이상입니다<br>
#             편리한 사이트 이용을 위하여 최신 브라우저로 업그레이드를 권장합니다
#         </p>
#         <div class="browser_list">
# 			<span class="list ie">
# 				<span class="title">Internet Explore</span>
# 			</span>
#             <span class="list firefox">
# 				<span class="title">Firefox</span>
# 			</span>
#             <span class="list chrome">
# 				<span class="title">Google Chrome</span>
# 			</span>
#             <span class="list safari">
# 				<span class="title">Safari</span>
# 			</span>
#         </div>
#         <div class="browser_close_chk">
# 			<span class="select_chk _old_browser_cookie">
# 				<input type="checkbox" id="item_browser" class="chk" checked="">
# 				<label class="lbl" for="item_browser">이 메세지를 다시 표시하지 않습니다</label>
# 			</span>
#         </div>
#         <a href="#" class="sp_btn_pop_close">
#             <span class="blind">권장 브라우저 안내 팝업 닫기</span>
#         </a>
#     </div>
# </div>
# <![endif]-->
# <script type="text/javascript">
# (function() {
#     window.$DATALAB = (typeof $DATALAB != "undefined") ? $DATALAB : {};
#     window.$DATALAB.CONFIG = (typeof $DATALAB.CONFIG != "undefined") ? $DATALAB.CONFIG : {};
#
#     $DATALAB.CONFIG.request_url = "'http://datalab.naver.com/keyword/realtimeList.naver?age=10s&amp;datetime=2020-09-21T14%3A00%3A00&amp;entertainment=-2&amp;groupingLevel=0&amp;marketing=-2&amp;news=-2&amp;sports=-2";
#     $DATALAB.CONFIG.realTimeOpenDate = "2020-01-16T06:00";
#
#     if(location.href.indexOf("dev") > 0) {
#         window.lcs_SerName = "alpha-lcs.naver.com";
#     }
# })();
# </script>
# <script src="https://ssl.pstatic.net/static.datalab/202004030222/js/vendor.202004030222.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.datalab/202004030222/js/realtime_v3.202004030222.js" type="text/javascript"></script>
# </body>
# </html>

# %%
# Ctrl + F 단축키를 통해 현재 네이버 실시간 검색어 중 하나를 검색해 출력한 웹페이지 내용에 존재하는지 확인합니다.
# 아래 예시는 "런닝맨"이 실시간 검색어 19위에 있음을 보여줍니다.

# %% [markdown]
# ~~~html
# <li class="ah_item" data-order="19">
#   <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%9F%B0%EB%8B%9D%EB%A7%A8&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%9F%B0%EB%8B%9D%EB%A7%A8&amp;sm=top_lve&amp;ie=utf8">
#     <span class="ah_r">19</span>
#     <span class="ah_k">런닝맨</span>
#   </a>
#   <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2019-06-03T04:45:00&amp;query=%EB%9F%B0%EB%8B%9D%EB%A7%A8&amp;where=main">
#     <span class="blind">데이터랩 그래프 보기</span>
#     <span class="ah_ico_datagraph"></span>
#   </a>
# </li>
# ~~~

# %%
# 5. Chrome 브라우저 [메뉴] > [도구 더보기] > [개발자도구] 메뉴를 통해 원하는 내용이 포함된 태그 확인 후 호출
# 위 웹페이지 예시에서 "런닝맨" 텍스트는 아래와 같이 <span> 태그로 둘러쌓여 있습니다.
# <span> 태그의 class 속성을 활용해 해당 태그만 가져올 수 있습니다.

# %% [markdown]
# ~~~html
# <span class="ah_k">런닝맨</span>
# ~~~

# %%
# 5-1) 태그이름과 class 속성으로 해당 태그를 가져옵니다.
tag_name = "span"
class_name = "item_title"
keyword = soup.find(tag_name, {'class': class_name,})
print(keyword)
# Out:
# <span class="item_title">어디가</span>

# %%
# 5-2) 동일한 태그이름과 class 속성을 가진 태그를 모두 가져옵니다.
# find 함수 대신 findAll 함수를 활용합니다.
tag_name = "span"
class_name = "item_title"
keyword_list = soup.findAll(tag_name, {'class': class_name,})

# %%
for keyword in keyword_list[:20]:
    print(keyword.text)
# Out:
# 어디가
# 아지땅
# 유웨이
# 배경화면
# 2021 신인드래프트
# 쇼타로
# nct
# 엔시티
# 성찬
# 엔시티 2020
# 케이타운포유
# 대학어디가
# 유웨이어플라이
# 동아대 코로나
# 어쩌다 결혼
# 엔하이픈
# 남영신
# 호서대학교
# 동국대학교
# 진학사 어플라이

# %%
# 태그가 저장된 변수에 get_text() 함수를 활용하면 태그로 둘러쌓인 텍스트만 가져올 수 있습니다.
for keyword in keyword_list[:20]:
    print(keyword.get_text())
# Out:
# 어디가
# 아지땅
# 유웨이
# 배경화면
# 2021 신인드래프트
# 쇼타로
# nct
# 엔시티
# 성찬
# 엔시티 2020
# 케이타운포유
# 대학어디가
# 유웨이어플라이
# 동아대 코로나
# 어쩌다 결혼
# 엔하이픈
# 남영신
# 호서대학교
# 동국대학교
# 진학사 어플라이

# %%
# 6. 가져온 데이터 정리해서 파일에 저장하기
# 새로운 파일을 생성해서 실시간 검색어를 저장합니다.
f = open("naver_search.txt", "w", encoding="utf-8")
for keyword in keyword_list[:20]:
    text = keyword.get_text()
    f.write(text + '\n')
f.close()

# %%
# 파일에 저장된 실시간 검색어를 불러옵니다.
f = open("naver_search.txt", encoding="utf-8")
for keyword in f:
    print(keyword.strip())
f.close()
# Out:
# 어디가
# 아지땅
# 유웨이
# 배경화면
# 2021 신인드래프트
# 쇼타로
# nct
# 엔시티
# 성찬
# 엔시티 2020
# 케이타운포유
# 대학어디가
# 유웨이어플라이
# 동아대 코로나
# 어쩌다 결혼
# 엔하이픈
# 남영신
# 호서대학교
# 동국대학교
# 진학사 어플라이

# %% [markdown]
# ### 2. 네이버 영화댓글 가져오기
#
# ---

# %%
# Python 코드를 통해 웹페이지에 정보를 요청하기 위해 BeautifulSoup, urllib 패키지를 import 합니다.
from bs4 import BeautifulSoup 
import urllib

# %%
# 1. 진짜 URL 찾기
# 네이버 영화댓글이 포함된 페이지의 URL을 가져옵니다.
URL = "https://movie.naver.com/movie/bi/mi/point.nhn?code=190010#tab"

# %%
# 2. urllib 패키지를 활용해 URL 호출하기
# 네이버 영화댓글 페이지 URL을 호출합니다.
response = requests.get(URL)

# %%
# 3. BeautifulSoup과 HtmlParser 패키지로 URL 호출 응답 불러오기
soup = BeautifulSoup(response.text, "html.parser")

# %%
# 4. 불러온 페이지에 원하는 내용이 포함되어있는지 PRINT 문으로 확인하기
# PRINT 문을 활용해 불러온 웹페이지 내용을 출력합니다.

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>테넷 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 테넷" property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1">
# <meta content="테넷" property="me2:category2"/>
# <meta content="테넷" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/bi/mi/point.nhn?code=190010" property="og:url"/>
# <meta content="https://movie-phinf.pstatic.net/20200728_86/15959209130236RePy_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content="시간의 흐름을 뒤집는 인버전을 통해 현재와 미래를 오가며 세상을 파괴하려는 사토르(케네스 브래너)를..." property="og:description"/>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# <meta content="네이버 영화" property="og:article:author"/>
# <meta content="https://movie.naver.com/" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/deploy/movie.all.css?20200806170632" rel="stylesheet" type="text/css">
# <script src="/js/deploy/movie.all.js?20200806170632" type="text/javascript"></script>
# </link></meta></meta></meta></head>
# <body>
# <div class="basic" id="wrap">
# <!-- GNB -->
# <script type="text/javascript">
# function delayed_submit(object) {
# 	if (navigator.userAgent.indexOf('MSIE') == -1) {
# 		var b = c = new Date();
#       	while ((b.getTime() - c.getTime()) < 100) {
# 			b = new Date();
#       	}
# 	}
# }
# </script>
# <script type="text/javascript">
# 	var gnb_service = "movie";
# 	var gnb_logout = "http://movie.naver.com/movie/bi/mi/point.nhn%3Fcode%3D190010";
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness=3;
# 	var gnb_response = true;
#
# 	jindo.$Fn(function(){
# 		getGNB();
# 	}).attach(window, "load");
#
# 	jindo.$Fn(function(oEvent){ var welSource = jindo.$Element(oEvent.element);
# 			if (!welSource.isChildOf(jindo.$Element("gnb"))) {
# 				gnbAllLayerClose();
# 			}
# 	}).attach(document, 'click');
# </script>
# <!-- skip navigation -->
# <div id="u_skip">
# <a href="#header" onclick="document.getElementById('header').tabIndex=-1;document.getElementById('header').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# <a href="#content" id="gnb_goContent" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# </div>
# <!-- //skip navigation -->
# <div class="gnb_container">
# <div class="gnb_content">
# <div class="gnb_box">
# <div class="gnb_wrap">
# <div id="gnb">
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn" type="text/javascript"></script>
# </div>
# </div>
# <!-- 검색창 -->
# <form action="/movie/search/result.nhn" id="jSearchForm" method="get" style="margin:0;display:none;">
# <input maxlength="100" name="query" title="영화검색" type="text"/>
# <input name="section" type="hidden" value="all"/>
# <input name="ie" type="hidden" value="utf8"/>
# </form>
# <fieldset class="srch_area" id="jSearchArea">
# <legend><span class="blind">영화검색 영역</span></legend>
# <div class="srch_field_on _view">
# <span class="ipt_srch">
# <label for="ipt_tx_srch" id="search_placeholder">영화검색</label>
# <input accesskey="s" autocomplete="off" class="ipt_tx_srch" id="ipt_tx_srch" maxlength="100" name="query" style="ime-mode:active;" type="text"/>
# <span class="align"></span>
# <span class="auto_tx"><a href="#" title="자동완성 펼치기"><img alt="자동완성 펼치기" height="4" src="https://ssl.pstatic.net/static/movie/2012/06/srch_arrow_down.gif" title="자동완성 펼치기" width="7"/></a></span>
# </span>
# <button class="btn_srch" onclick="clickcr(this,'GNB.search','','',event); delayed_submit(this);" title="검색" type="submit"><span class="blind">검색</span></button>
# <!-- 자동 완성 영역임 #autocomplate_template-->
# </div>
# </fieldset>
# <!-- //검색창 -->
# </div>
# </div>
# </div>
# <!-- //GNB -->
# <!-- header -->
# <div id="header">
# <a class="blind" href="#content" title="본문으로 이동">본문 바로가기</a>
# <h1 class="svc_name">
# <a class="ci_logo" href="http://www.naver.com/" id="lnb_gonaver" title="naver로 바로가기"><img alt="NAVER" height="13" src="https://ssl.pstatic.net/static/movie/2013/07/logo_ci.png" width="62"/></a><!-- N=a:LNB.naver -->
# <a class="svc_logo" href="/" title="영화서비스홈으로 바로가기"><img alt="영화" height="19" src="https://ssl.pstatic.net/static/movie/2012/06/logo_svc.png" width="34"/></a><!-- N=a:LNB.movie -->
# </h1>
# <div class="scrollbar scrollbar-noscript" id="scrollbar">
# <div class="scrollbar-box">
# <div class="scrollbar-content">
# <div class="in_scroll">
# <ul class="navi">
# <li>
# <a class="menu01" href="/" title="영화홈"><strong>영화홈</strong></a><!-- N=a:LNB.home -->
# </li>
# <li>
# <a class="menu02_on" href="/movie/running/current.nhn" title="상영작·예정작"><strong>상영작·예정작</strong></a><!-- N=a:LNB.movies -->
# <ul class="navi_sub" id="navi_movie" style="display:none">
# <li><a class="sub2_1_on" href="/movie/running/current.nhn" title="현재 상영영화"><em>현재 상영영화</em></a><!-- N=a:LNB.now --></li>
# <li><a class="sub2_2" href="/movie/running/premovie.nhn" title="개봉 예정영화"><em>개봉 예정영화</em></a><!-- N=a:LNB.soon --></li>
# <li><a class="sub2_4" href="/movie/running/movieclip.nhn" title="예고편"><em>예고편</em></a><!-- N=a:LNB.tailer --></li>
# </ul>
# </li>
# <li>
# <a class="menu03" href="/movie/sdb/rank/rmovie.nhn" title="영화랭킹"><strong>영화랭킹</strong></a><!-- N=a:LNB.db -->
# </li>
# <li>
# <a class="menu05" href="/movie/bi/mi/reserve.nhn" title="예매"><strong>예매</strong></a><!-- N=a:LNB.ticket -->
# </li>
# <li>
# <a class="menu07" href="/movie/point/af/list.nhn" title="평점·리뷰"><strong>평점·리뷰</strong></a><!-- N=a:LNB.comm -->
# </li>
# <li>
# <a class="menu08" href="https://serieson.naver.com/movie/home.nhn" target="_blank" title="다운로드"><strong>다운로드</strong></a><!-- N=a:LNB.download -->
# </li>
# <li class="nav_indi">
# <a href="http://tv.naver.com/indiecinema" target="_blank" title="인디극장 UP"><strong>인디극장 UP</strong></a><!-- N=a:LNB.indie -->
# </li>
# </ul>
# <!-- [D] view 모드 전환간 클래스는 _on,_off / 비활성화는 _disabled -->
# <div class="lnb_etc" id="viewmode-option-area">
# <div class="info_view">
# <a class="_info-anchor btn_view_md" href="#"><em>보기옵션</em></a>
# <div class="ly_info_view" id="_viewmode-option-info-layer" style="display:none">
# <span></span>
# 										브라우저의 해상도에 따라 기본 혹은 넓게보기가 가능합니다. 넓게보기는 가로해상도 1872픽셀 이상에서만 동작합니다.
# 									</div>
# </div>
# <div class="view_mode">
# <a class="_basic-btn normal_on" href="#" title=""><em>기본보기</em></a>
# <a class="_wide-btn wide_off" href="#" title=""><em>넓게보기</em></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="scrollbar-v">
# <div class="scrollbar-button-up"></div>
# <div class="scrollbar-track">
# <div class="scrollbar-thumb"></div>
# </div>
# <div class="scrollbar-button-down"></div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# 	if ("현재 상영영화" == "상영작·예정작"
# 			|| "현재 상영영화" == "현재 상영영화"
# 			|| "현재 상영영화" == "개봉 예정영화"
# 			|| "현재 상영영화" == "TV 방영영화"
# 			|| "현재 상영영화" == "예고편") {
# 		jindo.$Element("navi_movie").show();
# 	}
# 	</script>
# <!-- //header -->
# <!-- container -->
# <div id="container">
# <!-- 프로모션 레이어 -->
# <div class="ly_promo" id="thumb_promotion_layer"><h3>원하시는 영화를 선택해보세요.</h3>
# 			화제가 되고 있는 최신영화 정보를 한 눈에 확인하실 수 있습니다.
# 			<a class="btn_clse" href="#" id="thumb_promotion_layer_close" title="닫기">닫기</a>
# </div>
# <!-- 상단 현재 상영작 썸네일 리스트 -->
# <div class="spot">
# <div class="top_list" id="_TopArea">
# <div class="first_mv_list current_mv_list _mv_default_list">
# <button class="_prev-btn thumb_prev" onclick="clickcr(this,'rnk.prev','','',event);" type="button"><em>이전</em></button>
# <a class="h_current_mv" href="/movie/running/current.nhn?order=reserve" id="first_mv_list_link"><h2><strong class="blind">상영작 예매순위</strong></h2></a><!-- N=a:rnk.ntitle -->
# <div class="top_poster_area">
# <ul class="top_thumb_lst">
# <li class="on" data-title="테넷"><a href="/movie/bi/mi/basic.nhn?code=190010"><img alt="테넷" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200728_86/15959209130236RePy_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="뮬란"><a href="/movie/bi/mi/basic.nhn?code=167491"><img alt="뮬란" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_174/1598496595000hDi9H_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="오! 문희"><a href="/movie/bi/mi/basic.nhn?code=179859"><img alt="오! 문희" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200805_234/1596591608915HqeqM_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="기기괴괴 성형수"><a href="/movie/bi/mi/basic.nhn?code=194644"><img alt="기기괴괴 성형수" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200901_11/1598922866258hETJp_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="다만 악에서 구하소서"><a href="/movie/bi/mi/basic.nhn?code=189069"><img alt="다만 악에서 구하소서" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200706_191/1594001490577tifkl_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="테스와 보낸 여름"><a href="/movie/bi/mi/basic.nhn?code=183278"><img alt="테스와 보낸 여름" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200814_33/1597368744647OfBOS_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="뉴 뮤턴트"><a href="/movie/bi/mi/basic.nhn?code=164299"><img alt="뉴 뮤턴트" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200910_94/1599703996013taV6z_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!"><a href="/movie/bi/mi/basic.nhn?code=183772"><img alt="극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200806_196/1596705003939WIMwG_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="도망친 여자"><a href="/movie/bi/mi/basic.nhn?code=192191"><img alt="도망친 여자" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200728_203/1595913814604s1znL_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="매지컬: 공주를 웃겨라"><a href="/movie/bi/mi/basic.nhn?code=195967"><img alt="매지컬: 공주를 웃겨라" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200902_264/1599023779693070wc_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="지니어스 독"><a href="/movie/bi/mi/basic.nhn?code=195406"><img alt="지니어스 독" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_168/1598501717302lk8I4_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="더 렌탈: 소리없는 감시자"><a href="/movie/bi/mi/basic.nhn?code=195376"><img alt="더 렌탈: 소리없는 감시자" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200729_206/1596003966519nLjxA_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="비독: 파리의 황제"><a href="/movie/bi/mi/basic.nhn?code=182793"><img alt="비독: 파리의 황제" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_220/15985066611215US1B_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="남매의 여름밤"><a href="/movie/bi/mi/basic.nhn?code=189623"><img alt="남매의 여름밤" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200721_100/1595307510654a6eNC_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="에이바"><a href="/movie/bi/mi/basic.nhn?code=195377"><img alt="에이바" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200904_274/15991979769836Rx4f_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# </ul>
# </div>
# <button class="_next-btn thumb_next" onclick="clickcr(this,'rnk.next','','',event);" type="button"><em>다음</em></button>
# </div>
# <div class="second_mv_list expected_mv_list _mv_default_list">
# <button class="_prev-btn thumb_prev" onclick="clickcr(this,'rnk.prev','','',event);" type="button"><em>이전</em></button>
# <a class="h_expected_mv" href="/movie/running/premovie.nhn" id="second_mv_list_link"><h2><strong class="blind">예정작 개봉일순</strong></h2></a><!-- N=a:rnk.stitle -->
# <div class="top_poster_area">
# <ol class="top_thumb_lst">
# <li data-title="디바"><a href="/movie/bi/mi/basic.nhn?code=177039"><img alt="디바" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200904_26/159918499325176qGu_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="검객"><a href="/movie/bi/mi/basic.nhn?code=165287"><img alt="검객" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200828_213/1598582907899oLBjI_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="아웃포스트"><a href="/movie/bi/mi/basic.nhn?code=195450"><img alt="아웃포스트" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_33/1599618812553t64GX_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="구르는 수레바퀴"><a href="/movie/bi/mi/basic.nhn?code=189440"><img alt="구르는 수레바퀴" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200818_96/1597740320443U9WyB_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="극장판 엉덩이 탐정: 텐텐마을의 수수께끼"><a href="/movie/bi/mi/basic.nhn?code=196859"><img alt="극장판 엉덩이 탐정: 텐텐마을의 수수께끼" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200910_100/15997079459685APUj_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="프란시스 하"><a href="/movie/bi/mi/basic.nhn?code=98738"><img alt="프란시스 하" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200907_63/1599446725447uxvTw_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="다시 만난 날들"><a href="/movie/bi/mi/basic.nhn?code=195690"><img alt="다시 만난 날들" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200917_279/1600307438633Dai1n_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="보테로"><a href="/movie/bi/mi/basic.nhn?code=180264"><img alt="보테로" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200915_237/16001370233713S1wY_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="낙엽귀근"><a href="/movie/bi/mi/basic.nhn?code=66320"><img alt="낙엽귀근" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200914_163/1600053397206IrNH2_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="터칭 더 보이드"><a href="/movie/bi/mi/basic.nhn?code=38688"><img alt="터칭 더 보이드" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_108/1598508802876wyOsG_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="브레이크 더 사일런스: 더 무비"><a href="/movie/bi/mi/basic.nhn?code=195975"><img alt="브레이크 더 사일런스: 더 무비" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200917_291/1600333596388McCK9_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="윌라이즈 단편영화 기획전"><a href="/movie/bi/mi/basic.nhn?code=196365"><img alt="윌라이즈 단편영화 기획전" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net?type=n77_110_2" width="42"/></a></li>
# <li data-title="오전 0시, 키스하러 와줘"><a href="/movie/bi/mi/basic.nhn?code=190712"><img alt="오전 0시, 키스하러 와줘" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_65/1599629406791YJxea_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="국제수사"><a href="/movie/bi/mi/basic.nhn?code=175393"><img alt="국제수사" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200916_163/16002324767974gUSf_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# <li data-title="그대, 고맙소 : 김호중 생애 첫 팬미팅 무비"><a href="/movie/bi/mi/basic.nhn?code=196828"><img alt="그대, 고맙소 : 김호중 생애 첫 팬미팅 무비" height="60" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_27/1599613772180VMijj_JPEG/movie_image.jpg?type=n77_110_2" width="42"/></a></li>
# </ol>
# </div>
# <button class="_next-btn thumb_next" onclick="clickcr(this,'rnk.next','','',event);" type="button"><em>다음</em></button>
# </div>
# <a class="open_lst _expand-btn" href="#"><em class="blind" id="expandButtonName">상영예매순위, 예정작 개봉일순 더보기</em></a><!-- N=a:rnk.open -->
# <div class="open_mv_list _expansion-wrap" style="display:none">
# <div class="current_open">
# <div class="open_title_area">
# <h2 class="h_current_open">상영작 예매순위</h2>
# <a class="open_more" href="/movie/running/current.nhn?order=reserve" title="더보기"><em>더보기</em></a><!-- N=a:rnk.nmore -->
# </div>
# <ul class="current_list">
# <li class="on"><a href="/movie/bi/mi/basic.nhn?code=190010" title="테넷"><img alt="테넷" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200728_86/15959209130236RePy_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=167491" title="뮬란"><img alt="뮬란" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_174/1598496595000hDi9H_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=179859" title="오! 문희"><img alt="오! 문희" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200805_234/1596591608915HqeqM_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=194644" title="기기괴괴 성형수"><img alt="기기괴괴 성형수" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200901_11/1598922866258hETJp_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=189069" title="다만 악에서 구하소서"><img alt="다만 악에서 구하소서" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200706_191/1594001490577tifkl_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=183278" title="테스와 보낸 여름"><img alt="테스와 보낸 여름" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200814_33/1597368744647OfBOS_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=164299" title="뉴 뮤턴트"><img alt="뉴 뮤턴트" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200910_94/1599703996013taV6z_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=183772" title="극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!"><img alt="극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200806_196/1596705003939WIMwG_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=192191" title="도망친 여자"><img alt="도망친 여자" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200728_203/1595913814604s1znL_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195967" title="매지컬: 공주를 웃겨라"><img alt="매지컬: 공주를 웃겨라" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200902_264/1599023779693070wc_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195406" title="지니어스 독"><img alt="지니어스 독" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_168/1598501717302lk8I4_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195376" title="더 렌탈: 소리없는 감시자"><img alt="더 렌탈: 소리없는 감시자" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200729_206/1596003966519nLjxA_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=182793" title="비독: 파리의 황제"><img alt="비독: 파리의 황제" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_220/15985066611215US1B_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=189623" title="남매의 여름밤"><img alt="남매의 여름밤" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200721_100/1595307510654a6eNC_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195377" title="에이바"><img alt="에이바" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200904_274/15991979769836Rx4f_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=178687" title="카일라스 가는 길"><img alt="카일라스 가는 길" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200819_123/1597800319922Cfq3M_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=31130" title="공포분자"><img alt="공포분자" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200728_227/1595916020037z3gR6_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=80466" title="드라이브"><img alt="드라이브" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_204/1599617656986wzIGp_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=182120" title="어트랙션"><img alt="어트랙션" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200908_113/1599542183885Ek9A2_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=193330" title="나를 구하지 마세요"><img alt="나를 구하지 마세요" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200828_264/1598606865588n9WXo_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lnimg --></li>
# </ul>
# </div>
# <div class="expected_open">
# <div class="open_title_area">
# <h2 class="h_expected_open">예정작 개봉일순</h2>
# <a class="open_more" href="/movie/running/premovie.nhn" title="더보기"><em>더보기</em></a><!-- N=a:rnk.smore -->
# </div>
# <ol class="current_list">
# <li><a href="/movie/bi/mi/basic.nhn?code=177039" title="디바"><img alt="디바" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200904_26/159918499325176qGu_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=165287" title="검객"><img alt="검객" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200828_213/1598582907899oLBjI_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195450" title="아웃포스트"><img alt="아웃포스트" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_33/1599618812553t64GX_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=189440" title="구르는 수레바퀴"><img alt="구르는 수레바퀴" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200818_96/1597740320443U9WyB_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=196859" title="극장판 엉덩이 탐정: 텐텐마을의 수수께끼"><img alt="극장판 엉덩이 탐정: 텐텐마을의 수수께끼" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200910_100/15997079459685APUj_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=98738" title="프란시스 하"><img alt="프란시스 하" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200907_63/1599446725447uxvTw_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195690" title="다시 만난 날들"><img alt="다시 만난 날들" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200917_279/1600307438633Dai1n_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=180264" title="보테로"><img alt="보테로" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200915_237/16001370233713S1wY_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=66320" title="낙엽귀근"><img alt="낙엽귀근" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200914_163/1600053397206IrNH2_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=38688" title="터칭 더 보이드"><img alt="터칭 더 보이드" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200827_108/1598508802876wyOsG_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195975" title="브레이크 더 사일런스: 더 무비"><img alt="브레이크 더 사일런스: 더 무비" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200917_291/1600333596388McCK9_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=196365" title="윌라이즈 단편영화 기획전"><img alt="윌라이즈 단편영화 기획전" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=190712" title="오전 0시, 키스하러 와줘"><img alt="오전 0시, 키스하러 와줘" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_65/1599629406791YJxea_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=175393" title="국제수사"><img alt="국제수사" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200916_163/16002324767974gUSf_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=196828" title="그대, 고맙소 : 김호중 생애 첫 팬미팅 무비"><img alt="그대, 고맙소 : 김호중 생애 첫 팬미팅 무비" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_27/1599613772180VMijj_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=195983" title="그린랜드"><img alt="그린랜드" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200916_44/1600222960705E8Pg1_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=183866" title="담보"><img alt="담보" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200914_157/1600059933290PCKwd_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=183854" title="죽지않는 인간들의 밤"><img alt="죽지않는 인간들의 밤" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200909_147/1599614480817jHOPg_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=188465" title="우리가 이별 뒤에 알게 되는 것들"><img alt="우리가 이별 뒤에 알게 되는 것들" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200907_249/1599446192328BSgv9_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# <li><a href="/movie/bi/mi/basic.nhn?code=189393" title="교실 안의 야크"><img alt="교실 안의 야크" height="110" onerror="src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110.png'" src="https://movie-phinf.pstatic.net/20200910_92/1599711981305fdQMq_JPEG/movie_image.jpg?type=n77_110_2" width="77"/></a><!-- N=a:rnk.lsimg --></li>
# </ol>
# </div>
# </div>
# </div>
# </div>
# <!-- //상단 현재 상영작 썸네일 리스트 -->
# <script id="_TopAreaThumbnailExpander_tpl" type="text/template">
#             <div class="zoom_img" style="width:77px;height:110px;left:{=nLeft}px">
#                 <a href="{=sUrl}">
#                     <span class="img_mask">
#                             <p>{=sTitle}</p>
#                     </span>
#                     <img src="{=sImgSrc}" alt="" />
#                 </a>
#             </div>
#         </script>
# <script type="text/javascript">
# 			jindo.$Fn(
# 				function (we) {
# 					if (jindo.$('thumb_promotion_layer') != null) {
# 						jindo.$Fn(
# 							function(e) {
# 								jindo.$Element("thumb_promotion_layer").hide();
# 								jindo.$Cookie().set("NM_THUMB_PROMOTION_BLOCK", "Y", 1000);	//1000 days
# 							}
# 						).attach(jindo.$("thumb_promotion_layer_close"), "click").attach(jindo.$("_TopArea"), "click");
# 					}
# 				}
# 			).attach(document, 'domready');
#         </script>
# <!-- content -->
# <div id="content">
# <input id="movieCode" name="movieCode" type="hidden" value="190010"/>
# <input id="pointAfterActualPointYn" name="pointAfterActualPointYn" type="hidden" value=""/>
# <input id="pointAfterOrder" name="pointAfterOrder" type="hidden" value=""/>
# <input id="pointAfterPage" name="pointAfterPage" type="hidden" value="1"/>
# <input id="pointBeforeInterestYn" name="pointBeforeInterestYn" type="hidden" value=""/>
# <input id="pointBeforePage" name="pointBeforePage" type="hidden" value="1"/>
# <input id="point" name="point" type="hidden" value="0"/>
# <div class="article">
# <!-- 영화정보(wide) -->
# <div class="wide_info_area" style="display: none">
# <!-- 포스터 -->
# <div class="poster">
# <a href="#" onclick="javascript:common.iwopen('190010');clickcr(this,'ifo.img','','',event);return false;"><img alt="테넷" onerror="this.src='https://ssl.pstatic.net/static/movie/2012/06/dft_img77x110_1.png'" src="https://movie-phinf.pstatic.net/20200728_86/15959209130236RePy_JPEG/movie_image.jpg?type=m77_110_2"/><span>포스터 크게보기</span></a>
# </div>
# <!-- //포스터 -->
# <div class="mv_info">
# <h3 class="h_movie">
# <a href="./basic.nhn?code=190010">테넷</a><!-- N=a:ifo.title -->
# <a class="opening" href="/movie/running/current.nhn?order=reserve"><em>상영중</em></a><!-- N=a:ifo.nbtn -->
# <strong class="h_movie2" title="TENET										, 					2020">TENET
#
# 					,
# 					2020</strong>
# </h3>
# <div class="main_score">
# <div class="score">
# <div class="uio_ntz_btn see">
# <span class="ntz _actualPointHelpWide">
# <em class="blind">관람객 평점</em>
# <a class="help _actualPointHelpWide" href="#" id="actualPointHelpButtonWide">관람객 평점 도움말</a>
# </span>
# <div class="ly_ntz _actualPointHelpWide" id="actualPointHelpWide" style="display:none">
# <span></span>
# 							관람객 평점은 네이버영화에서<br/>예매하고 실제 관람 후 이용자들이<br/>작성한 평점입니다.
# 							<button class="btn_close _actualPointHelpWide" id="actualPointHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="actualPointCountWide" style="display:none">
# <span></span>
# 							참여 <em>1,539</em>명
# 						</div>
# </div>
# <a class="ntz_score" href="./point.nhn?code=190010&amp;onlyActualPointYn=Y#pointAfterTab" id="actualPointPersentWide">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:87.9%">관람객 평점 8.79점</span></span><em class="num8">8</em><em class="dot">.</em><em class="num7">7</em><em class="num9">9</em>
# </div>
# </a><!-- N=a:ifo.mgrating -->
# </div>
# <div class="score">
# <div class="spc_score_area">
# <a class="spc" href="./point.nhn?code=190010#pointExpertTab">
# <span class="spc_score"><em class="blind">기자 · 평론가 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:71.8%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num1">1</em><em class="num8">8</em>
# </div>
# </a><!-- N=a:ifo.crating -->
# </div>
# </div>
# <div class="score">
# <div class="uio_ntz_btn">
# <span class="ntz">
# <em class="blind">네티즌 평점</em><a class="help" href="#" id="pointHelpButtonWide" title="네티즌 평점 도움말 보기">네티즌 평점 도움말</a>
# </span>
# <div class="ly_ntz _pointHelpWide" id="pointHelpWide" style="display:none">
# <span></span>
#
#
#
# 								국내 개봉작입니다. 관람하신 영화에 대한<br/> 평점을 남겨주세요. 네티즌 평점 뿐 아니라 블<br/>로그 영화 리뷰작성 시 등록한 별점도 함께<br/> 반영됩니다.
#
#
# 						<button class="btn_close _pointHelpWide" id="pointHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="pointNetizenCountWide" style="display:none">
# <span></span>
# 						참여 <em>8,425</em>명
# 					</div>
# </div>
# <div class="star_score ">
# <a href="./point.nhn?code=190010#pointAfterTab" id="pointNetizenPersentWide"><span class="st_off"><span class="st_on" style="width:82.7%"></span></span><em class="num8">8</em><em class="dot">.</em><em class="num2">2</em><em class="num7">7</em></a><!-- N=a:ifo..arating -->
# </div>
# </div>
# <div class="score" id="noPointWide">
# <div class="my_score_area">
# <!--[D] 내평점이 없는경우 화살표를 없애기 위해 class="my"가 빠진다 -->
# <a href="./point.nhn?code=190010#pointAfterTab">
# <span class="my_score"><em class="blind">내 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:0%">0점</span></span>
# <span class="btn_write">등록</span>
# </div>
# </a>
# </div>
# </div>
# <div class="score" id="existPointWide" style="display : none">
# <div class="my_score_area">
# <a class="my" href="javascript:pointWide.toggleMyPoint();">
# <span class="my_score">
# <em class="blind">내 평점</em>
# </span>
# <div class="star_score" id="starPointWide">
# <span class="st_off"><span class="st_on" id="pointStarWide" style="width:0%"></span></span>
# </div>
# </a><!-- N=a:ifo.marating -->
# <div class="ly_my" id="myPointLayerWide" style="display:none">
# <span id="pointTextWide"></span><a class="btn_del" href="javascript:checkAlreadyPointAfterExist('wide', );" id="pointRemoveWide">삭제</a>
# <a class="btn_close" href="javascript:pointWide.toggleMyPoint();"><em>닫기</em></a>
# </div>
# </div>
# </div>
# </div>
# <p class="info_spec">
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a>,
#
#
#
# 				<a href="/movie/sdb/browsing/bmovie.nhn?genre=18">SF</a>
# </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?nation=GB">영국</a>
# 				,
#
#
#
# 				<a href="/movie/sdb/browsing/bmovie.nhn?nation=US">미국</a>
# </span>
# <span>150분 </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=2020">2020</a>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=20200826">.08.26</a> 개봉
#
#
#
# 				</span>
# <span>
# 					[국내]
#
# 							<a href="/movie/sdb/browsing/bmovie.nhn?grade=1001002">12세 관람가</a>
# </span>
# <span><a href="/movie/running/current.nhn?view=list&amp;tab=normal&amp;order=reserve">예매율 1위</a></span>
# <span class="uio_ntz_btn">
# <span class="ntz">누적관객<a class="help" href="#" id="boxofficeHelpButtonWide" title="누적관객 도움말 보기">누적관객 도움말</a></span>
# <span class="ly_ntz" id="boxofficeHelpLayerWide" style="display:none;">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
# 						영화진흥위원회 영화관 입장권 통합전산망 제공
# 						<button class="btn_close" id="boxofficeHelpCloseButtonWide" type="button"><em>닫기</em></button>
# </span>
# </span><span class="count">1,536,373명<em>(09.20 기준)</em></span>
# </p>
# <div class="info_spec2">
# <dl class="step1">
# <dt>감독</dt>
# <dd>
# <a href="/movie/bi/pi/basic.nhn?code=261">크리스토퍼 놀란</a>
# </dd>
# </dl>
# <dl class="step2">
# <dt>출연</dt>
# <dd>
# <a href="/movie/bi/pi/basic.nhn?code=196965">존 데이비드 워싱턴<span></span></a>,
#
#
#
#
#
#
#
#
#
# 									<a href="/movie/bi/pi/basic.nhn?code=49023">로버트 패틴슨<span>(닐)</span></a>,
#
#
#
#
#
#
#
#
#
# 									<a href="/movie/bi/pi/basic.nhn?code=318463">엘리자베스 데비키<span>(캣)</span></a>
# </dd>
# </dl>
# <a class="more" href="./detail.nhn?code=190010" title="더보기">더보기</a>
# </div>
# <div class="end_btn_area">
# <ul>
# <li><a class="btn_rsv _reserveHelpWide" href="/movie/bi/mi/reserve.nhn?code=190010" id="reserveWide" title="예매하기"><em>예매하기</em></a>
# <div class="ly_mileage _reserveHelpWide" id="reserveHelpWide" style="display:none">
# <span></span>영화관람후 평점을 작성하시면 <em>네이버페이 포인트 500원</em>을 드립니다! <a class="btn_close _reserveHelpWide" href="#" id="reserveHelpWideCloseButton"><em>닫기</em></a>
# </div>
# </li>
# <li>
# <div class="u_likeit_module"></div>
# </li>
# </ul>
# </div>
# <div class="spi_area">
# <div class="naver-splugin" data-me-display="off" data-oninitialize="movie_oninitialize()" data-style="standard-v1-text" id="wideSpiLayer"></div>
# </div>
# </div>
# <!--[D] 성별 나이별 관람추이 -->
# <div class="viewing_graph">
# <h4 class="graph_title">성별·나이별 관람추이</h4>
# <div class="graph_wrap">
# <div class="donut_graph">
# <div class="graph_box" id="actualGenderGraph_wide" style="width: 100px;height:100px;">
# </div>
# <div class="graph_legend">
# <ul>
# <li>남자</li>
# <li>여자</li>
# </ul>
# </div>
# </div>
# <div class="bar_graph">
# <div class="graph_box ">
# <strong class="graph_percent">3<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 3%"></span>
# </div>
# <strong class="graph_legend"><span class="num">10</span>대</strong>
# </div>
# <div class="graph_box high_percent">
# <strong class="graph_percent">51<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 51%"></span>
# </div>
# <strong class="graph_legend"><span class="num">20</span>대</strong>
# </div>
# <div class="graph_box ">
# <strong class="graph_percent">29<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 29%"></span>
# </div>
# <strong class="graph_legend"><span class="num">30</span>대</strong>
# </div>
# <div class="graph_box ">
# <strong class="graph_percent">12<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 12%"></span>
# </div>
# <strong class="graph_legend"><span class="num">40</span>대</strong>
# </div>
# <div class="graph_box ">
# <strong class="graph_percent">6<span class="text_percent">%</span></strong>
# <div class="graph">
# <span class="bar_gauge" style="height: 6%"></span>
# </div>
# <strong class="graph_legend"><span class="num">50</span>대 <span class="ico_up"><span class="blind">이상</span></span></strong>
# </div>
# </div>
# </div>
# </div>
# <!--// 성별 나이별 관람추이 -->
# </div>
# <!-- //영화정보(wide) -->
# <!-- 영화정보(basic) -->
# <div class="mv_info_area">
# <div class="mv_info">
# <h3 class="h_movie">
# <a href="./basic.nhn?code=190010">테넷</a><!-- N=a:ifo.title --> <a class="opening" href="/movie/running/current.nhn?order=reserve"><em>상영중</em></a><!-- N=a:ifo.nbtn --></h3>
# <strong class="h_movie2" title="TENET, 2020">TENET, 2020</strong>
# <div class="main_score">
# <div class="score">
# <div class="uio_ntz_btn see">
# <span class="ntz _actualPointHelpBasic">
# <em class="blind">관람객 평점</em>
# <a class="help _actualPointHelpBasic" href="#" id="actualPointHelpButtonBasic">관람객 평점 도움말</a>
# </span>
# <div class="ly_ntz" id="actualPointHelpBasic" style="display:none" z-index="20">
# <span></span>
# 							관람객 평점은 네이버영화에서<br/>예매하고 실제 관람 후 이용자들이<br/>작성한 평점입니다.
# 							<button class="btn_close _actualPointHelpBasic" id="actualPointHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="actualPointCountBasic" style="display:none">
# <span></span>
# 							참여 <em>1,539</em>명
# 						</div>
# </div>
# <a class="ntz_score" href="./point.nhn?code=190010&amp;onlyActualPointYn=Y#pointAfterTab" id="actualPointPersentBasic">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:87.9%">관람객 평점 8.79점</span></span><em class="num8">8</em><em class="dot">.</em><em class="num7">7</em><em class="num9">9</em>
# </div>
# </a><!-- N=a:ifo.mgrating -->
# </div>
# <div class="score">
# <div class="spc_score_area">
# <a class="spc" href="./point.nhn?code=190010#pointExpertTab">
# <span class="spc_score"><em class="blind">기자 · 평론가 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:71.8%"></span></span><em class="num7">7</em><em class="dot">.</em><em class="num1">1</em><em class="num8">8</em>
# </div>
# </a><!-- N=a:ifo.crating -->
# </div>
# </div>
# <div class="score score_left">
# <div class="uio_ntz_btn">
# <span class="ntz">
# <em class="blind">네티즌 평점</em><a class="help" href="#" id="pointHelpButtonBasic" title="네티즌 평점 도움말 보기">네티즌 평점 도움말</a>
# </span>
# <div class="ly_ntz" id="pointHelpBasic" style="display:none" z-index="20">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
#
#
#
# 								국내 개봉작입니다. 관람하신 영화에 대한<br/> 평점을 남겨주세요. 네티즌 평점 뿐 아니라 블<br/>로그 영화 리뷰작성 시 등록한 별점도 함께<br/> 반영됩니다.
#
#
# 						<button class="btn_close" id="pointHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </div>
# <div class="ly_count" id="pointNetizenCountBasic" style="display:none">
# <span></span>
# 						참여 <em>8,425</em>명
# 					</div>
# </div>
# <div class="star_score ">
# <a href="./point.nhn?code=190010#pointAfterTab" id="pointNetizenPersentBasic"><span class="st_off"><span class="st_on" style="width:82.7%"></span></span><em class="num8">8</em><em class="dot">.</em><em class="num2">2</em><em class="num7">7</em></a><!-- N=a:ifo.arating -->
# </div>
# </div>
# <div class="score" id="noPoint">
# <div class="my_score_area">
# <!--[D] 내평점이 없는경우 화살표를 없애기 위해 class="my"가 빠진다 -->
# <a href="./point.nhn?code=190010#pointAfterTab">
# <span class="my_score"><em class="blind">내 평점</em></span>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:0%">0점</span></span>
# <span class="btn_write">등록</span>
# </div>
# </a>
# </div>
# </div>
# <div class="score" id="existPoint" style="display : none">
# <div class="my_score_area">
# <a class="my" href="javascript:pointBasic.toggleMyPoint();">
# <span class="my_score">
# <em class="blind">내 평점</em>
# </span>
# <div class="star_score" id="starPoint">
# <span class="st_off"><span class="st_on" id="pointStar" style="width:0%"></span></span>
# </div>
# </a><!-- N=a:ifo.marating -->
# <div class="ly_my" id="myPointLayerBasic" style="display:none">
# <span id="pointText"></span><a class="btn_del" href="javascript:checkAlreadyPointAfterExist('basic', );" id="pointRemove">삭제</a>
# <a class="btn_close" href="javascript:pointBasic.toggleMyPoint();"><em>닫기</em></a>
# </div>
# </div>
# </div>
# </div>
# <dl class="info_spec">
# <dt class="step1"><em>개요()</em></dt>
# <dd>
# <p>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?genre=19">액션</a><!-- N=a:ifo.genre -->,
#
#
#
# 					<a href="/movie/sdb/browsing/bmovie.nhn?genre=18">SF</a><!-- N=a:ifo.genre -->
# </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?nation=GB">영국</a><!-- N=a:ifo.nation -->
# 					,
#
#
#
# 					<a href="/movie/sdb/browsing/bmovie.nhn?nation=US">미국</a><!-- N=a:ifo.nation -->
# </span>
# <span>150분 </span>
# <span>
# <a href="/movie/sdb/browsing/bmovie.nhn?open=2020"> 2020</a><!-- N=a:ifo.year -->
# <a href="/movie/sdb/browsing/bmovie.nhn?open=20200826">.08.26</a><!-- N=a:ifo.day --> 개봉
#
#
#
# 					</span>
# </p>
# </dd>
# <dt class="step2"><em>감독</em></dt>
# <dd><p><a href="/movie/bi/pi/basic.nhn?code=261">크리스토퍼 놀란</a><!-- N=a:ifo.director --></p></dd>
# <dt class="step3"><em>출연</em></dt>
# <dd><p><a href="/movie/bi/pi/basic.nhn?code=196965">존 데이비드 워싱턴</a><!-- N=a:ifo.actor -->, <a href="/movie/bi/pi/basic.nhn?code=49023">로버트 패틴슨</a><!-- N=a:ifo.actor -->(닐), <a href="/movie/bi/pi/basic.nhn?code=318463">엘리자베스 데비키</a><!-- N=a:ifo.actor -->(캣)</p><a class="more" href="detail.nhn?code=190010" title="더보기">더보기</a><!-- N=a:ifo.actmore --></dd>
# <dt class="step4"><em>등급</em></dt>
# <dd>
# <p>
# 						[국내]
#
# 							<a href="/movie/sdb/browsing/bmovie.nhn?grade=1001002">12세 관람가</a><!-- N=a:ifo.filmrate -->
# </p>
# </dd>
# <dt class="step9"><em>흥행</em></dt>
# <dd>
# <div class="step9_cont">
# <p class="rate"><a href="/movie/running/current.nhn?view=list&amp;tab=normal&amp;order=reserve">예매율 1위</a></p>
# <div class="uio_ntz_btn">
# <span class="ntz">누적관객<a class="help" href="#" id="boxofficeHelpButtonBasic" title="누적관객 도움말 보기">누적관객 도움말</a></span>
# <div class="ly_ntz" id="boxofficeHelpLayerBasic" style="display:none;">
# <span></span>
# <strong class="blind">네티즌 평점 도움말</strong>
# 									영화진흥위원회 영화관 입장권 통합전산망 제공
# 									<button class="btn_close" id="boxofficeHelpCloseButtonBasic" type="button"><em>닫기</em></button>
# </div>
# </div>
# <p class="count">1,536,373명<span>(09.20 기준)</span></p>
# </div>
# </dd>
# </dl>
# <!--[D] 성별 나이별 관람추이 -->
# <div class="viewing_graph">
# <h4 class="graph_title">성별·나이별 관람추이</h4>
# <div class="graph_wrap">
# <div class="donut_graph">
# <div class="graph_box" id="actualGenderGraph" style="width: 100px;height:100px;">
# <!--[D] 그래프 영역 -->
# </div>
# <div class="graph_legend">
# <ul>
# <li>남자</li>
# <li>여자</li>
# </ul>
# </div>
# </div>
# <div class="bar_graph">
# ...
# 				!jindo.$Element("spoilerY").hasClass('checked')
# 				&& !jindo.$Element("spoilerN").hasClass('checked')) {
#               alert('스포일러를 선택해주세요.');
#               return false;
#             }
#
#             if (point == 0){
#               alert('별점을 선택해 주세요');
#               return false;
#             }
#
#             if (point > 10){
#               alert('별점은 10점까지만 입력이 가능합니다.');
#               return false;
#             }
#
#             this.pwmManager.startFilter('comment', function(){}, new Array('평점'), new Array(ment));
#
#             if (checkInput && !isUpdate) {
#               return false;
#             }
#
#             checkInput = true;
#
#             //ajax전송
#             var ajaxAddUrl = "/api/internal/point/pointBeforeWrite.nhn";
#               body.directing = jindo.$Element("direc").hasClass('checked') ? 'Y' : 'N';
#               body.acting = jindo.$Element("acting").hasClass('checked') ? 'Y' : 'N';
#               body.story = jindo.$Element("story").hasClass('checked') ? 'Y' : 'N';
#               body.visual = jindo.$Element("video").hasClass('checked') ? 'Y' : 'N';
#               body.ost =  jindo.$Element("ost").hasClass('checked') ? 'Y' : 'N';
#               body.spoiler = jindo.$Element("spoilerY").hasClass('checked') ? 'Y' : null;
#               body.spoiler = jindo.$Element("spoilerN").hasClass('checked') ? 'N' : body.spoiler;
#               ajaxAddUrl = "/api/internal/point/pointAfterWrite.nhn";
#
#             var ajax = new jindo.$Ajax(ajaxAddUrl, {
#               method : "POST",
#               async : false,
#               onload : this.addCallback
#             });
#             ajax.header("ajax", "true");
#             ajax.request(body);
#           }
#           return;
#         },
#
#         addCallback : function(req) {
#           isUpdate = false;
#           var returnValue = req.text();
#
#           if (returnValue != "success") {
#             alert(returnValue);
#             checkInput = false;
#             return;
#           }
#
#           jindo.$("pointAfterListIframe").contentDocument.location.reload(true);
#           alert("평점 등록이 완료되었습니다.");
#           jindo.$Element("point-write-form").hide();
#         },
#
#         checkPointAfterExistAndMileageSubscriptionType : function () {
#           var existPointType = "pointBefore";
#
#           var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistAndMileageSubscriptionTypeJson.nhn", {
#             onload : function (oRes) {
#               var resultCode = oRes.json().resultCode;
#
#               if (resultCode == "error") {							// 서버 오류
#                 alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
#               } else {
#
#                 existPointType = oRes.json().existPointType;
#
#                 if (false && existPointType == "afterPoint") {			// 실관람 평점 작성 가능
#                   bActualPoint = true;
#
#                   if(confirm("관람객 평점 작성 시, 이전에 작성한 평점은 삭제됩니다.") == false) {
#                     return false;
#                   }
#                 }
#
#
#                 if (false) {
#                   var mileageSubscriptionType = oRes.json().mileageSubscriptionType;
#
#                   if (mileageSubscriptionType == "NOT_AGREED_WITH_NEW_TERMS") {
#                     jindo.$Element("naverMileageSubscriptionLayer").show();
#                     return false;
#                   } else if (mileageSubscriptionType == "AGREED_WITH_NEW_TERMS") {
#                     bMileageSubscriptionAlready = true;
#                   } else if (mileageSubscriptionType == "POSSIBLE") {
#                     jindo.$Element("naverMileageSubscriptionLayer").show();
#                     return false;
#                   } else if (mileageSubscriptionType == "STOP") {
#                     alert("현재 포인트 서비스 중지 상태로 약관동의 및 적립이 불가능합니다.");
#                     return false;
#                   } else if (mileageSubscriptionType == "IMPOSSIBLE_PERIOD") {
#                     alert("회원님은 네입페이 서비스 약관동의 불가 기간으로 약관동의 및 적립이 불가능합니다.");
#                     return false;
#                   } else if (mileageSubscriptionType == "DUPLICATES_REAL_NAME") {
#                     alert("회원님의 실명 아이디 3개가 모두 네이버페이 서비스 이용 중이어서 약관동의 및 적립이 불가능합니다.");
#                     return false;
#                   } else if (mileageSubscriptionType == "ALREADY") {
#                     bMileageSubscriptionAlready = true;
#                   } else {
#                     alert("비정상적인 접근입니다.");
#                     return false;
#                   }
#                 }
#               }
#             },
#             timeout : 5,
#             onerror : function (oRes) {
#               alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
#             },
#             ontimeout : function (oRes) {
#               alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
#             }
#           });
#
#           oAjax.request({
#             "movieCode" : "190010",
#             "isActualPoint" : "false"
#           });
#         }
#       };
#
#       if(jindo.$Element("btn_interest_point") != null && jindo.$Element("btn_notInterest_point") != null) {
#
#         //기대지수 도움말 레이어 토글.
#         new jindo.LayerManager("preference_help_point", {
#           sCheckEvent : "click",
#           nHideDelay : 0
#         }).link(jindo.$("preference_help_point"), jindo.$("preference_help_show_point"));
#
#         jindo.$Element("preference_help_show_point").attach("click", function(e){
#           e.stop(jindo.$Event.CANCEL_DEFAULT);
#           jindo.$Element("preference_help_point").toggle();
#         });
#
#         jindo.$Element("preference_close_point").attach("click", function(e){
#           e.stop(jindo.$Event.CANCEL_DEFAULT);
#           jindo.$Element("preference_help_point").hide();
#         });
#
#         //
#         preferenceHelpLayerToggle = function() {
#           setTimeout( function() {
#             if (document.activeElement != null) {
#               var focusedEl = jindo.$Element(document.activeElement);
#               if (focusedEl != null) {
#                 if ( !focusedEl.hasClass("_preferenceHelp") ) {
#                   jindo.$Element("preference_help_point").hide();
#                 }
#               }
#             }
#           }, 100);
#         };
#
#         var waelPreferenceHelp = jindo.$ElementList('._preferenceHelp');
#
#         jindo.$A(waelPreferenceHelp.$value()).forEach(function(value, index, array) {
#           jindo.$Fn(preferenceHelpLayerToggle, this).attach(value, "blur");
#         });
#       }
#       // defGenre: 액션
#
# 	  // 감상평 입력 필드 focus 이벤트 발생
# 	  jindo.$Element("ment").attach("focus", function(e) {
# 	      jindo.$Element(this).addClass("active");
# 	  });
#
# 	  // 감상평 입력 필드 blur 이벤트 발생
# 	  jindo.$Element("ment").attach("blur", function(e) {
# 	      if (jindo.$(this).value == "") {
#               jindo.$Element(this).removeClass("active");
# 		  }
# 	  });
# 	</script>
# </div>
# <!-- //content -->
# </div>
# <!-- //container -->
# <!-- footer -->
# <div id="footer">
# <div class="in_footer">
# <div class="foot_con">
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" target="_blank">이용약관</a><!-- N=a:fot.agreement --></li>
# <li><a href="http://www.naver.com/rules/privacy.html" target="_blank"><strong>개인정보처리방침</strong></a><!-- N=a:fot.privacy --></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" target="_blank">책임의 한계와 법적고지</a><!-- N=a:fot.disclaimer --></li>
# <li><a href="https://help.naver.com/support/service/main.nhn?serviceNo=800" target="_blank">영화 고객센터</a><!-- N=a:fot.help --></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <p class="info">
# 					사업자등록번호 : 220-81-62517<span>통신판매업 신고번호</span> : 경기성남 제 2006 - 692호<span>대표이사 : 한성숙</span><span><a href="http://www.ftc.go.kr/info/bizinfo/communicationList.jsp">사업자등록정보 확인</a><!-- N=a:fot.bizinfo --></span><br/>
# 					주소 : 경기도 성남시 분당구 불정로 6 네이버 그린팩토리 <span>대표전화 : 1588-3820</span>
# </p>
# <address>
# <a class="logo" href="http://www.navercorp.com/" target="_blank"><img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/movie/2013/07/logo_naver.png" width="63"/></a><!-- N=a:fot.nhn -->
# <em>Copyright ©</em>
# <a href="http://www.navercorp.com/" target="_blank">NAVER Corp.</a><!-- N=a:fot.corp -->
# <span>All Rights Reserved.</span>
# </address>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# if (false) {
# 	var alertType = "NONE";
# 	var koreanTitle = "";
# 	var movieCode = "0";
# 	var userReserveCount = "0";
# 	var todayDatetime = "20200921215618";
# 	var endDatetimeAfterTwoDays = "00000000000000";
#
#
# 	if (movieCode > 0) {
# 		openWriteActualPointAlert (alertType, koreanTitle, movieCode, userReserveCount, todayDatetime, endDatetimeAfterTwoDays);
# 	}
# }
#
# function openWriteActualPointAlert (alertType, koreanTitle, movieCode, count, today, endDate) {
# 	if (alertType == "ONE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 " + koreanTitle + "에\n평점 등록 시 네이버페이 포인트 500원 적립!\n지금 평점쓰기 메뉴로 이동하시겠습니까?")) {
# 			top.location.href = "https://movie.naver.com/movie/bi/mi/point.nhn?code=" + movieCode;
# 		}
# 	} else if (alertType == "MORE") {
# 		setCookieLastUserReserveDate(today, endDate);
# 		if (confirm("관람하신 작품에 평점을 등록해주세요\n작품당 네이버페이 포인트 500원씩 적립!\n평점 미등록작 리스트를 확인하시겠습니까?")) {
# 			top.location.href = "http://ticket.movie.naver.com/Order/OverdueList.aspx";
# 		}
# 	}
# }
#
# function setCookieLastUserReserveDate(today, endDate) {
# 	var cookieForNotOpenActualPointPopup = jindo.$Cookie();
#
#
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveDatetime");
# 	cookieForNotOpenActualPointPopup.remove("lastUserReserveCheckDatetime");
#
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveDatetime", endDate, 9999, "movie.naver.com");
# 	cookieForNotOpenActualPointPopup.set("lastUserReserveCheckDatetime", today, 9999, "movie.naver.com");
# }
#
# </script>
# <script type="text/javascript">
#
#
#
#
#
# 			var alertMessage = "지원되지 않는 브라우저로 서비스 이용에 제한이 있습니다.";
#
#
#
# 	function getBrowser() {
# 		var ua = navigator.userAgent;
# 		if (/NAVER/.test(ua)) {
# 			return "NAVER_APP";
# 		} else if (/IEMobile/.test(ua)) {
# 			return "INTERNET_EXPLORER_MOBILE";
# 		} else if (/MSIE/.test(ua) || /Trident/.test(ua)) {
# 			return "INTERNET_EXPLORER";
# 		} else if (/Firefox/.test(ua)) {
# 			return "FIREFOX";
# 		} else if (/Opera\//.test(ua) || /OPR\//.test(ua)) {
# 			return "OPERA";
# 		}  else if (/Swing\//.test(ua)) {
# 			return "SWING";
# 		} else if (/Chrome\//.test(ua) || /CriOS\//.test(ua)) {
# 			return "CHROME";
# 		} else if (/BAND\//.test(ua)) {
# 			return "BAND_APP";
# 		} else if (/FBAN\/FBIOS/.test(ua)) {
# 			return "FACEBOOK_APP";
# 		} else if (/Twitter/.test(ua)) {
# 			return "TWITTER_APP";
# 		} else if (/KAKAOTALK/.test(ua)) {
# 			return "KAKAOTALK_APP";
# 		} else if (/Android/.test(ua) && /Safari/.test(ua)) {
# 			return "ANDROID_INTERNET_APP";
# 		} else if (/Safari/.test(ua)) {
# 			return "SAFARI";
# 		}
#
# 		return "";
# 	}
#
# 	if (getBrowser() === "UNKNOWN" && jindo.$Cookie().get("notSupportBrowserAlert") != 'true') {
# 		alert(alertMessage);
# 		jindo.$Cookie().set("notSupportBrowserAlert", "true", "9999", "movie.naver.com");
# 	}
#
#
# </script>
# <!-- //footer -->
# </div>
# <script type="text/javascript">
# var isRecentTab = false;
#
# jindo.$Fn(function (we) {
#
# 	    // 윈도우창 리사이징에 따른 레이아웃 1/2단 관리
# 	    var oViewMode = new nhn.movie.end.ViewMode();
#
#
# 	// 상단 검색영역
# 	var oSearch = new nhn.movie.Search({
# 		area : "jSearchArea",
# 		autosearch : "https://auto-movie.naver.com/ac?q_enc=UTF-8&st=1&r_lt=1&n_ext=1&t_koreng=1&r_format=json&r_enc=UTF-8&r_unicode=0&r_escape=1&q=",
# 		movelink : "/movie/bi/mi/basic.nhn?code=",
# 		peoplelink : "/movie/bi/pi/basic.nhn?code="
# 	});
#
#     // 좌측 LNB
#     var oLNB = new nhn.movie.LNB();
# 	if( typeof oViewMode != "undefined") {
# 		oViewMode.attach('change', jindo.$Fn(oLNB.update, oLNB).bind());
# 	}
#
#     // 2단일때, 2열에 상단 회색 라인 없애기
# 	if( typeof oViewMode != "undefined") {
# 	    oViewMode.attach('change', function (oEvent) {
# 	        var welSecondSectionGroup = jindo.$Element('content').queryAll('.section_group')[1];
# 	        var wel2column1rowSection;
#
# 	        if (welSecondSectionGroup) {
# 	            wel2column1rowSection = welSecondSectionGroup.query('.obj_section');
#
# 	            if (oEvent.sStyle == 'wide') {
# 	                wel2column1rowSection.addClass('noline');
# 	            } else {
# 	                wel2column1rowSection.removeClass('noline');
# 	            }
# 	        }
#
# 		    //포토 묻어가기
# 		    if( typeof oPhoto != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oPhoto.setWide("wide");
# 			    } else {
# 				    oPhoto.setWide("basic");
# 			    }
# 		    }
# 		    // 비디오 묻어가기
# 		    if( typeof oMovie != "undefined" ){
# 			    if (oEvent.sStyle == 'wide') {
# 				    oMovie.setWide("wide", 1);
# 			    } else {
# 				    oMovie.setWide("basic", 1);
# 			    }
# 		    }
#
# 	    });
# 	}
#
#     // 상단썸네일영역
#
#
# 		var welTopArea = jindo.$Element('_TopArea');
# 		new nhn.movie.end.TopAreaThumbnailExpander(welTopArea.query('.current_mv_list .top_poster_area')).attach({
# 		    click: function (oEvent) {
# 		        clickcr(oEvent.element, 'rnk.nimg', '', '', event);
# 		    }
# 		});
# 		new nhn.movie.end.TopAreaThumbnailExpander(welTopArea.query('.expected_mv_list .top_poster_area')).attach({
# 		    click: function (oEvent) {
# 		        clickcr(oEvent.element, 'rnk.simg', '', '', event);
# 		    }
# 		});
# 		var oTopAreaManager = new nhn.movie.end.movie.TopAreaManager(welTopArea);
# 		if ( typeof oViewMode == "undefined" || oViewMode.is('basic') ) {
# 		    oTopAreaManager.enableNavigationBtns();
# 		} else {
# 		    oTopAreaManager.disableNavigationBtns();
# 		}
# 		if( typeof oViewMode != "undefined" ) {
# 			var tempEvent = {};
# 			oViewMode.attach('change', jindo.$Fn(oTopAreaManager.onViewModeChange, oTopAreaManager).bind());
#
# 		    if (oViewMode.is('basic') && oViewMode.serverSstyle != 'basic') {
# 		    	tempEvent.sStyle = 'basic';
# 			    oTopAreaManager.onViewModeChange(tempEvent);
# 		    } else if (oViewMode.is('wide') && oViewMode.serverSstyle != 'wide') {
# 		    	tempEvent.sStyle = 'wide';
# 			    oTopAreaManager.onViewModeChange(tempEvent);
# 		    }
# 		}
#
#
#
#
#     var waelScriptOrderList = jindo.$ElementList('._gnb_another_service_layer');
#
#     jindo.$A(waelScriptOrderList.$value()).forEach(function(value, index, array) {
# 		jindo.$Fn(reviewOrderLayerToggle, this).attach(value, "blur");
# 	});
#     //자동닫힘 기능 끝.
#
#   //영화검색 결과에서 포커스 아웃될 경우, 검색 결과를 지우도록 변경.
#     jindo.$Element("lnb_gonaver").attach("focus",function(e){
#
#     	jindo.$Element('search_placeholder').attr({
#     		"style" : "display: inline;"
#     	})
#     	jindo.$Element('ipt_tx_srch').$value().value="";
#
#     	if(jindo.$Element("jAutoComplate") != null){
#     		jindo.$Element("jAutoComplate").hide();
#     	}
#     });
#
#
#     /**
#      * 영화 END 페이지
#      */
#     var welMovieInfoWideArea = jindo.$Element(jindo.$$.getSingle('.wide_info_area'));
#     var welMovieInfoBasicArea = jindo.$Element(jindo.$$.getSingle('.mv_info_area'));
#     if ( oViewMode.is('basic') ) {
#         welMovieInfoWideArea.hide();
#         welMovieInfoBasicArea.show();
#       	if (window["createActualGenderPointGraph"]) createActualGenderPointGraph();
#     } else {
#         welMovieInfoBasicArea.hide();
#         welMovieInfoWideArea.show();
#       	if(window["createActualGenderPointGraph"]) createActualGenderPointGraph(true);
#     }
#     oViewMode.attach('change', function (oEvent) {
#         // 기본정보 영역 변경
#         if ( oEvent.sStyle === 'basic' ) {
#             welMovieInfoWideArea.hide();
#             welMovieInfoBasicArea.show();
#           if(window["createActualGenderPointGraph"]) createActualGenderPointGraph();
#         } else {
#             welMovieInfoBasicArea.hide();
#             welMovieInfoWideArea.show();
#
#           if(window["createActualGenderPointGraph"]) createActualGenderPointGraph(true);
#         }
#     });
#
#
#
#
#
#
#
#         /* 영화 평점 탭 */
#
#
#
#
#
#
#
#
#
#
# }).attach(document, 'domready');
# /**
#  * 기타 공통
#  */
# jindo.$Fn(function() {
#     try{ lcs_do(); } catch(e){}
# }).attach(window, "pageshow");
# </script>
# <script type="text/javascript">
# 	//nClick 초기화 영역
# 	//클릭로그 집계 코드 추가
# 	var ccsrv="cc.naver.com";
# 	var nclk_evt = 1;
#
# 	nclk_do();
# 	//nClick 초기화 영역 끝
# </script>
# </body>
# </html>

# %%
# Ctrl + F 단축키를 통해 댓글 중 하나의 일부 또는 전체를 검색해 출력한 웹페이지 내용에 존재하는지 확인합니다.
# 해당 웹페이지 내용에 댓글이 존재하지 않습니다.
# 다시 "1.진짜 URL 찾기" 과정으로 돌아갑니다.

# %%
# 1. 진짜 URL 찾기
# 네이버 영화댓글이 포함된 페이지의 URL을 가져옵니다.
URL = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=167491&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page=2"

# %%
# 2. urllib 패키지를 활용해 URL 호출하기
# 네이버 영화댓글 페이지 URL을 호출합니다.
response = requests.get(URL)

# %%
# 3. BeautifulSoup과 HtmlParser 패키지로 URL 호출 응답 불러오기
soup = BeautifulSoup(response.text, "html.parser")

# %%
# 4. 불러온 페이지에 원하는 내용이 포함되어있는지 PRINT 문으로 확인하기
# PRINT 문을 활용해 불러온 웹페이지 내용을 출력합니다.

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20200806170632" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20200806170632" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20200806170632" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20200806170632" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="167491"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# <input id="page" name="page" type="hidden" value="2"/>
# <div class="ifr_area basic_ifr">
# <div class="input_netizen ">
# <!-- [D] 관람객 평점 작성 완료 -->
# <div class="ly_viewer" id="actualPointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p>관람객 평점이 등록되었습니다.<br/><em>네이버페이 포인트 500원</em>이 적립되었습니다.<br/><em>7일 이후</em> 확인 가능합니다.</p>
# <p>(평점 삭제시, 적립된 포인트는 회수됩니다.)</p>
# <div class="btn">
# <a class="ok" href="#" id="actualPointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="actualPointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료 -->
# <!-- [D] 관람객 평점 작성 완료2 -->
# <div class="ly_viewer" id="pointWriteExecuteLayer" style="display:none">
# <h4>관람객 평점 작성 완료 안내</h4>
# <p class="msg1">관람객 평점이 등록되었습니다.</p>
# <div class="btn">
# <a class="ok" href="#" id="pointWriteExecuteLayerOkButton">확인</a>
# <a class="close" href="#" id="pointWriteExecuteLayerCloseButton" title="닫기">관람객 평점 작성 완료 안내 레이어 닫기</a>
# </div>
# </div>
# <!-- //관람객 평점 작성 완료2 -->
# <div class="score_total">
# <strong class="total">관람객 평점 <em>2,903</em>건<button class="btn_review" id="open-form-btn">내 평점 등록</button></strong>
# </div>
# <div class="top_behavior" id="orderCheckbox">
# <ul class="sorting_list">
# <li class="on"><a href="#" onclick="parent.clickcr(this, 'ara.bysym', '', '', event); dislplayOrder('sympathyScore');">공감순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.byrct', '', '', event); dislplayOrder('newest');">최신순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.high', '', '', event); dislplayOrder('highest');">평점 높은 순</a></li>
# <li><a href="#" onclick="parent.clickcr(this, 'ara.low', '', '', event); dislplayOrder('lowest');">평점 낮은 순</a></li>
# </ul>
# <ul class="quarter_mode">
# <li>
# <input class="blind " id="spoilerYnCheckBox" name="spilerViewer" onclick="parent.clickcr(this,'','','',event); return false;" title="스포일러 보기" type="checkbox"/>
# <label class="label_viewer" for="spoilerYnCheckBox" id="spoilerYnLable">스포일러 보기</label>
# </li>
# <li>
# <input class="blind " id="actualYnCheckBox" name="viewer" onclick="parent.clickcr(this,'ura.mgs','','',event); return false;" title="관람객 평점만 보기" type="checkbox"/>
# <label class="label_viewer" for="actualYnCheckBox" id="actualYnLable">관람객 평점만 보기</label>
# <a class="help _actualPointHelp" href="#" id="actualPointHelpButton" title="도움말">관람객 평점만 보기 도움말</a>
# <div class="ly_help _actualPointHelp" id="actualPointHelp" style="display:none">
# <h5>관람객평점만 보기 안내 레이어</h5>
# <div class="ly_cont _actualPointHelp">
# <p>네이버 영화에서 예매하신 고객님들이<br/> 영화 관람 후 등록해주신 평점입니다.</p>
# </div>
# <button class="btn_close _actualPointHelp" id="actualPointHelpCloseButton" title="닫기" type="button"><span class="blind">관람객 평점만 보기 안내 레이어 닫기</span></button>
# <span class="arr _actualPointHelp"></span>
# </div>
# </li>
# </ul>
# </div>
# <div class="score_result">
# <ul>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
# <span class="_unfold_ment" id="_unfold_ment0">
# <a data-src="일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈니 원작이 있으니 당연히 좋은건데.. 정말 이렇게 만들지 몰랐다... ㅡ_ㅡ 다들 무거운 진지충 연기... 초등학교 고학년 이상의 아이들은 몰라도 영유아나 저학년 아이들이 집중력있게 볼 수 있을만한 작품은 아닌듯... " href="javascript:void(0);" onclick="unfoldPointMent(this);">
# 																		일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈...
# 																	</a>
# </span>
# </span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17147646, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>Vinn(kyoo****)</span>
# </a>
# </em>
# <em>2020.09.19 02:31</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','kyoo****', 'nmFn+lL2KeFT5ZoHIhDbG2k3P86TYvl4c3IquFNHHpU=', '일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈니 원작이 있으니 당연히 좋은건데.. 정말 이렇게 만들지 몰랐다... ㅡ_ㅡ 다들 무거운 진지충 연기... 초등학교 고학년 이상의 아이들은 몰라도 영유아나 저학년 아이들이 집중력있게 볼 수 있을만한 작품은 아닌듯... ', '17147646', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17147646">155</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17147646">16</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:30.0%"></span></span><em>3</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span class="text_spo _text_spo" id="_text_spo_1">스포일러가 포함된 감상평입니다. <a class="btn_more" href="javascript:void(0);" onclick="showMovieReview('1');" role="button">감상평 보기</a></span>
# <span id="_filtered_ment_1" style="display:none;">
# <span class="_unfold_ment" id="_unfold_ment1">
# <a data-src="애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장인물들의 노래가 없었던 것도 의아함. " href="javascript:void(0);" onclick="unfoldPointMent(this);">
# 																		애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장...
# 																	</a>
# </span>
# </span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17146549, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>alle****</span>
# </a>
# </em>
# <em>2020.09.18 17:29</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','alle****', 'xdeQdzxXnSb6KaNf46Wl14zOt61MS3vj8ukyuFym8FA=', '애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장인물들의 노래가 없었던 것도 의아함. ', '17146549', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17146549">150</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17146549">22</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																디즈니..넘 실망....어떻게 그럴수있니
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143657, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>토이스토리(gpff****)</span>
# </a>
# </em>
# <em>2020.09.17 13:15</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gpff****', 'URZd73KZKH4uXJYvL9OzNMUUDprapk62ZlBZxfEV2gQ=', '디즈니..넘 실망....어떻게 그럴수있니 ', '17143657', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17143657">137</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17143657">19</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:20.0%"></span></span><em>2</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																개봉하기전에 이미 봤다...ㅋㅋㅋㅋ견자단하고 이연걸 아깝다... 여기 왜 출연했어..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143509, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>므두셀라(hone****)</span>
# </a>
# </em>
# <em>2020.09.17 11:27</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','hone****', 'fm6oo1zRnjWcRpm1pH2igrxSW4hfSvgtW2vdAL+3PxU=', '개봉하기전에 이미 봤다...ㅋㅋㅋㅋ견자단하고 이연걸 아깝다... 여기 왜 출연했어.. ', '17143509', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17143509">108</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17143509">14</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																돈으로 헐리우드를 샀지만 관객마음은 못사지
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143592, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>ys(cysp****)</span>
# </a>
# </em>
# <em>2020.09.17 12:30</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','cysp****', 'y0yEb1PWwjudR1kUrRPoZS6lA7ttuzIjf1GyfqX+tqU=', '돈으로 헐리우드를 샀지만 관객마음은 못사지 ', '17143592', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17143592">101</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17143592">10</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																내 어린시절 뮬란을 이렇게 망치지마
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143801, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>현욱(unti****)</span>
# </a>
# </em>
# <em>2020.09.17 14:31</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','unti****', 'MRiScv8QprhiB3k1aPH6lHfIxkX8SOUiJKK+STNaEZ0=', '내 어린시절 뮬란을 이렇게 망치지마 ', '17143801', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17143801">94</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17143801">6</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																영화에 짜장이 묻으면 이 꼴 나는구나 ㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143417, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>반찬우(banc****)</span>
# </a>
# </em>
# <em>2020.09.17 10:09</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','banc****', 'A7PYKKEhV2v7woMVN4RqqsOxFCgECtyYSxk5wRiPW1M=', '영화에 짜장이 묻으면 이 꼴 나는구나 ㅋ ', '17143417', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17143417">106</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17143417">18</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:40.0%"></span></span><em>4</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																이번만큼은 동의 합니다. 찌꺼기라는 평론가의 평점을..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143726, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>올마이티히터(stap****)</span>
# </a>
# </em>
# <em>2020.09.17 13:55</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','stap****', 'mWhYWFYNiD194Ub8AiZc2b+qBy9UmQXz+y5+TRdDMOQ=', '이번만큼은 동의 합니다. 찌꺼기라는 평론가의 평점을.. ', '17143726', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17143726">87</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17143726">5</strong>
# </a>
# </div>
# </li>
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:20.0%"></span></span><em>2</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span class="text_spo _text_spo" id="_text_spo_8">스포일러가 포함된 감상평입니다. <a class="btn_more" href="javascript:void(0);" onclick="showMovieReview('8');" role="button">감상평 보기</a></span>
# <span id="_filtered_ment_8" style="display:none;">
#
#
#
# 																음.... 알라딘은 예술성이 돋보였지만 뮬란은 ost도 없도 그냥 애니 줄거리만을 따라가기만 한 느낌 이에요... 감동도 예술성도 돋보이지 않고 밋밋해 실망스럽습니다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17147442, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>구예은(sjo5****)</span>
# </a>
# </em>
# <em>2020.09.19 00:51</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sjo5****', 'TuVsCq3NWDe+P8rSJDTET4Vv0VMN7aD5IQSJIzOqeXk=', '음.... 알라딘은 예술성이 돋보였지만 뮬란은 ost도 없도 그냥 애니 줄거리만을 따라가기만 한 느낌 이에요... 감동도 예술성도 돋보이지 않고 밋밋해 실망스럽습니다 ', '17147442', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17147442">97</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17147442">18</strong>
# </a>
# </div>
# </li>
# <li class="last">
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:10.0%"></span></span><em>1</em>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																중국이 싫다고 1점 주지는 맙시다. 저는 이 영화가 싫어서 1점 줍니다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143575, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>포지트론(inhy****)</span>
# </a>
# </em>
# <em>2020.09.17 12:24</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','inhy****', 'aHJmZghelfrJi625/28/Ozro+mJYsBLVArvr0J0vOYs=', '중국이 싫다고 1점 주지는 맙시다. 저는 이 영화가 싫어서 1점 줍니다. ', '17143575', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# <a class="_sympathyButton" href="#" onclick="parent.clickcr(this, 'ara.sym', '', '', event);">
# <span class="ico_up"></span>
# <span class="blind">공감</span>
# <strong class="sympathy_17143575">84</strong>
# </a>
# <a class="_notSympathyButton" href="#" onclick="parent.clickcr(this, 'ara.opp', '', '', event);">
# <span class="ico_down"></span>
# <span class="blind">비공감</span>
# <strong class="notSympathy_17143575">7</strong>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paging">
# <div>
# <a class="pg_prev" href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="이전"><em>이전</em></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=1" id="pagerTagAnchor1" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>1</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=2" id="pagerTagAnchor2" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span class="on">2</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>3</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=4" id="pagerTagAnchor4" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>4</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=5" id="pagerTagAnchor5" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>5</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=6" id="pagerTagAnchor6" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>6</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=7" id="pagerTagAnchor7" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>7</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=8" id="pagerTagAnchor8" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>8</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=9" id="pagerTagAnchor9" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>9</span></a>
# <a href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=10" id="pagerTagAnchor10" onclick="parent.clickcr(this, 'ara.page', '', '', event);"><span>10</span></a>
# <a class="pg_next" href="/movie/bi/mi/pointWriteFormList.nhn?code=167491&amp;type=after&amp;isActualPointWriteExecute=false&amp;isMileageSubscriptionAlready=false&amp;isMileageSubscriptionReject=false&amp;page=3" id="pagerTagAnchor3" onclick="parent.clickcr(this, 'ara.page', '', '', event);" title="다음"><em>다음</em></a>
# </div>
# </div>
# </div>
# </div>
# <!-- //content -->
# <form accept-charset="euc-kr" id="reportForm" method="POST" name="reportForm1"></form>
# <script type="text/javascript">
#
#
# if (false == false && "after" == "after" && false) {
# 	if (true && false) {
# 		jindo.$Element("pointWriteExecuteLayer").show();
# 	} else if (false && true) {
# 		jindo.$Element("actualPointWriteExecuteLayer").show();
# 	}
# }
#
# var oElActualPointWriteExecuteLayer = jindo.$Element("actualPointWriteExecuteLayer");
#
# if (oElActualPointWriteExecuteLayer != null && oElActualPointWriteExecuteLayer != "undefined") {
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("actualPointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("actualPointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# var oElPointWriteExecuteLayer = jindo.$Element("pointWriteExecuteLayer");
#
# if (oElPointWriteExecuteLayer != null && oElPointWriteExecuteLayer != "undefined") {
#
# 	jindo.$Element("pointWriteExecuteLayerOkButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
#
#
# 	jindo.$Element("pointWriteExecuteLayerCloseButton").attach("click", function(e){
# 		e.stop(jindo.$Event.CANCEL_DEFAULT);
# 		jindo.$Element("pointWriteExecuteLayer").hide();
# 		refreshPage();
# 	});
#
# }
#
# jindo.$Fn(function () {
#
#   function checkboxHandlerFactory(isActualYn, isLabel) {
#     return function() {
#       var actualYnChecked = jindo.$("actualYnCheckBox").checked;
#       var spoilerYnChecked = jindo.$("spoilerYnCheckBox").checked;
#
#       // convert
#       actualYnChecked = (isActualYn && isLabel)? !actualYnChecked : actualYnChecked;
#       spoilerYnChecked = (!isActualYn && isLabel)? !spoilerYnChecked : spoilerYnChecked;
#
#       location.href = "/movie/bi/mi/pointWriteFormList.nhn?code=167491&type=after&onlyActualPointYn=" + (actualYnChecked? "Y" : "N")  + "&onlySpoilerPointYn=" + (spoilerYnChecked? "Y" : "N") + "&order=sympathyScore";
#     };
#   }
#
#
# 	if (jindo.$("actualYnCheckBox") != null) {
# 		jindo.$Fn(checkboxHandlerFactory(true, false), this).attach(jindo.$("actualYnCheckBox"), 'click');
# 	}
#
# 	if (jindo.$("actualYnLable") != null) {
# 	    jindo.$Fn(checkboxHandlerFactory(true, true), this).attach(jindo.$("actualYnLable"), 'click');
# 	}
#
#
#     if (jindo.$("spoilerYnCheckBox") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, false), this).attach(jindo.$("spoilerYnCheckBox"), 'click');
#   }
#
#   if (jindo.$("spoilerYnLable") != null) {
#     jindo.$Fn(checkboxHandlerFactory(false, true), this).attach(jindo.$("spoilerYnLable"), 'click');
#   }
#
#
# 	if (jindo.$Element("actualPointHelp") != null && jindo.$Element("actualPointHelp") != "undefined") {
# 		actualPointHelpLayerToggle = function() {
# 			setTimeout( function() {
# 				if (document.activeElement != null) {
# 					var focusedEl = jindo.$Element(document.activeElement);
# 					if (focusedEl != null) {
# 						if ( !focusedEl.hasClass("_actualPointHelp") ) {
# 							 jindo.$Element("actualPointHelp").hide();
# 						}
# 					}
# 				}
# 			}, 100);
# 		};
#
# 		new jindo.LayerManager("actualPointHelp", {
# 			sCheckEvent : "click",
# 			nHideDelay : 0
# 		}).link(jindo.$("actualPointHelp"), jindo.$("actualPointHelpButton"));
#
# 		jindo.$Element("actualPointHelpButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
# 		jindo.$Element("actualPointHelpCloseButton").attach("click", function(e){
# 			e.stop(jindo.$Event.CANCEL_DEFAULT);
# 			jindo.$Element("actualPointHelp").toggle();
# 		});
#
#
# 		var waelActualPointHelp = jindo.$ElementList('._actualPointHelp');
#
# 		jindo.$A(waelActualPointHelp.$value()).forEach(function(value, index, array) {
# 			jindo.$Fn(actualPointHelpLayerToggle, this).attach(value, "blur");
# 		});
# 	}
#
# 	parent.setParamForPointAfterList('N', 'sympathyScore', '2');
# 	parent.resizePointAfterListIframe(0);
#
# 	// 최소 높이 270px 지정
# 	var frameHeight = eval(jindo.$Document().scrollSize().height);
#
# 	parent.resizePointAfterListIframe(frameHeight);
# 	parent.isPointAfterListLoad = true;
#
#
#
# 		if (true) {
# 			jindo.$("pagerTagAnchor3").focus();
# 		} else if (jindo.$("pagerTagAnchor2") != null ){
# 			jindo.$("pagerTagAnchor2").focus();
# 		}
#
#
#   var isCheckPointExist = false;
#   // TODO: fix below condition
#   if (false) {
#     if(jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function(e) {
#
#
#
# 		  if (true && false && isCheckPointExist == false) {
# 			parent.point.checkPointAfterExistAndMileageSubscriptionType();
# 		  }
# 		  isCheckPointExist = true;
# 		  parent.openPointWriteForm();
# 		});
#     }
#   } else {
#     if (jindo.$Element("open-form-btn")) {
# 		jindo.$Element("open-form-btn").attach("click", function (e) {
# 		  common.checkLogin(false);
# 		});
#     }
#   }
#
#   var isHide = true;
#
#   if(jindo.$Element("eval-edit")) {
#     jindo.$Element("eval-edit").attach("click", function() {
# 		  var edit = jindo.$Element("ly-edit");
# 	  	isHide ? edit.show() : edit.hide();
#       	isHide = !isHide;
#     })
#   }
#   parent.resizePointAfterListIframeOnLoad();
# }, this).attach(this, 'load');
#
# var point = {
# 		checkLoginWithMessage : function(login, loginMessage, notLoginMessage) {
# 			if(login == false){
# 				if(confirm(message)){
# 					top.location.href="https://nid.naver.com/nidlogin.login?mode=form&url="+encodeURIComponent(top.location.href);
# 				}
# 				return false;
# 			}
# 			return true;
# 		},
#
#
# 		checkAlreadyPointAfterExist : function (nid) {
# 			var existPointType = "pointBefore";
#
# 			if (false == false) {
# 				var oAjax = new jindo.$Ajax("/api/internal/point/pointAfterExistJson.nhn", {
# 			    	onload : function (oRes) {
# 			    		var resultCode = oRes.json().resultCode;
#
# 			    		if (resultCode == "error") {							// 서버 오류
# 			    			alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    			return false;
# 			    		} else {
# 			    			existPointType = oRes.json().existPointType;
# 			    			point.del(existPointType, nid);
# 			    		}
# 			    	},
# 					timeout : 5,
# 			    	onerror : function (oRes) {
# 			    		alert("오류가 발생했습니다. 잠시 후 다시 시도해주세요.");
# 			    		return false;
# 			    	},
# 			    	ontimeout : function (oRes) {
# 			    		alert("처리가 지연되고 있습니다. 다시 시도해주세요.");
# 			    		return false;
# 			    	}
# 			    });
#
# 			    oAjax.request({
# 			    	"movieCode" : "167491",
# 			    	"isActualPoint" : "false"
# 			    });
# 			} else {
# 				point.del(existPointType, nid);
# 			}
# 		},
#
# 		del : function (existPointType, nid) {
# 			if (existPointType == "actualPoint") {
# 				if (confirm("관람객 평점 삭제시, 평점 작성으로 적립된 포인트는 회수됩니다. 평점을 삭제할까요?") == false) {
# 					return false;
# 				}
# 			} else {
# 				if (confirm("본인 삭제 시 복구할 수 없습니다.\n평점을 삭제하시겠습니까?") == false) {
# 					return false;
# 				}
# 			}
#
# 			var ajaxDeleteUrl = "/api/internal/point/pointBeforeDelete.nhn";
# 			if ("after" == "after") {
# 				ajaxDeleteUrl = "/api/internal/point/pointAfterDelete.nhn";
# 			}
#
# 			var ajax = new jindo.$Ajax(ajaxDeleteUrl, {
# 				method : "POST",
# 				async : false,
# 				onload : this.delCallback
# 			});
# 			ajax.header("ajax", "true");
# 			ajax.request({
# 				"nid":nid
# 			});
# 		},
#
# 		delCallback : function(req) {
# 			var returnValue = req.text();
#
# 			if(returnValue != "success"){
# 				alert(returnValue);
# 				return false;
# 			}
#
# 			top.location.href = '/movie/bi/mi/point.nhn?code=167491#pointAfterTab';
# 			top.location.reload(true);
# 		}
# };
#
# function dislplayOrder(order) {
# 	var url = "/movie/bi/mi/pointWriteFormList.nhn?code=167491&type=after";
#
# 	var onlyActualPointYnValue = jindo.$("onlyActualPointYn").value;
#   	var includeSpoilerYnValue = jindo.$("includeSpoilerYn").value;
#
# 	if (onlyActualPointYnValue != "") {
# 		url = url + "&onlyActualPointYn=" + onlyActualPointYnValue;
# 	}
#
# 	if (includeSpoilerYnValue != "") {
#       url = url + "&onlySpoilerPointYn=" + includeSpoilerYnValue;
#     }
#
# 	url = url + "&order=" + order;
#
# 	location.href = document.location.protocol + "//" + document.domain + url;
# }
#
# function showPointListByNid(nid, target){
# 	if (target == 'after') {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname&target=after&sword="+nid;
# 	} else {
# 		top.location.href = top.location.protocol + "//" + top.location.hostname + "/movie/point/af/list.nhn?st=nickname_before&target=before&sword="+nid;
# 	}
# }
#
# function refreshPage() {
#
# 	top.location.href = '/movie/bi/mi/point.nhn?code=167491#pointAfterTab';
# }
#
# // 스포일러 감상평 내용 보기
# function showMovieReview(rvwIdx) {
#     jindo.$Element('_text_spo_' + rvwIdx).css('display', 'none');
#     jindo.$Element('_filtered_ment_' + rvwIdx).css('display', 'block');
#     parent.resizePointAfterListIframeOnLoad();
# }
#
# // 감상평 펼쳐보기
# function unfoldPointMent(obj) {
#     var fullMent = jindo.$Element(obj).attr("data-src");
#     jindo.$Element(obj).parent().html(fullMent);
#     parent.resizePointAfterListIframeOnLoad();
# }
#
#
# </script>
# <script type="text/javascript">
# 	var sympathy = new Sympathy("167491", "after");
# </script>
# <script type="text/javascript">
#             jindo.$Fn(function() {
#                 try{ lcs_do(); } catch(e){}
#             }).attach(window, "pageshow");
# 		</script>
# </body>
# </html>

# %% [markdown]
# ~~~html
# <div class="score_reple">
#   <p>마블 3000만큼 사랑합니다  </p>
#   <dl>
#     <dt>
#       <em>
#         <a href="#" onclick="javascript:showPointListByNid(15535812, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
#           <span>전은호(eunh****)</span>
#         </a>
#       </em>
#       <em>2019.04.24 10:31</em>
#     </dt>
#     <dd>
#       <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','eunh****', 'uv551WV2CAQ0fZUWTaiFpIb20w73doxxmi6uj3BLyPs=', '마블 3000만큼 사랑합니다 ', '15535812', 'point_after', false);return false;"><em>신고</em></a>
#     </dd>
#   </dl>
# </div>
# ~~~

# %%
# 5. Chrome 브라우저 [메뉴] > [도구 더보기] > [개발자도구] 메뉴를 통해 원하는 내용이 포함된 태그 확인 후 호출
# 위 웹페이지 예시에서 "마블 3000만큼 사랑합니다" 텍스트는 <p> 태그로 둘러쌓여 있습니다.
# <p> 태그로도 해당 부분을 가져올 수 있지만 정확도를 높이기 위해 그 상위태그인 <div> 태그를 활용합니다.
# <div> 태그의 class 속성을 활용해 해당 태그만 가져올 수 있습니다.

# %%
# 5-2) 동일한 태그이름과 class 속성을 가진 태그를 모두 가져옵니다.
# 한 페이지에 댓글이 여러개 존재하므로 find 함수 대신 findAll 함수를 활용합니다.
tag_name = "div"
class_name = "score_reple"
comment_list = soup.findAll(tag_name, {'class': class_name,})

# %%
# 웹페이지에서 댓글을 태그로 특정할때 <p> 태그가 아닌 상위태그 <div>를 활용했기 때문에 <div> 태그 하위태그가 모두 출현합니다.
for comment in comment_list:
    print(comment)
# Out:
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
# <span class="_unfold_ment" id="_unfold_ment0">
# <a data-src="일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈니 원작이 있으니 당연히 좋은건데.. 정말 이렇게 만들지 몰랐다... ㅡ_ㅡ 다들 무거운 진지충 연기... 초등학교 고학년 이상의 아이들은 몰라도 영유아나 저학년 아이들이 집중력있게 볼 수 있을만한 작품은 아닌듯... " href="javascript:void(0);" onclick="unfoldPointMent(this);">
# 																		일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈...
# 																	</a>
# </span>
# </span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17147646, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>Vinn(kyoo****)</span>
# </a>
# </em>
# <em>2020.09.19 02:31</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','kyoo****', 'nmFn+lL2KeFT5ZoHIhDbG2k3P86TYvl4c3IquFNHHpU=', '일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈니 원작이 있으니 당연히 좋은건데.. 정말 이렇게 만들지 몰랐다... ㅡ_ㅡ 다들 무거운 진지충 연기... 초등학교 고학년 이상의 아이들은 몰라도 영유아나 저학년 아이들이 집중력있게 볼 수 있을만한 작품은 아닌듯... ', '17147646', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span class="text_spo _text_spo" id="_text_spo_1">스포일러가 포함된 감상평입니다. <a class="btn_more" href="javascript:void(0);" onclick="showMovieReview('1');" role="button">감상평 보기</a></span>
# <span id="_filtered_ment_1" style="display:none;">
# <span class="_unfold_ment" id="_unfold_ment1">
# <a data-src="애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장인물들의 노래가 없었던 것도 의아함. " href="javascript:void(0);" onclick="unfoldPointMent(this);">
# 																		애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장...
# 																	</a>
# </span>
# </span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17146549, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>alle****</span>
# </a>
# </em>
# <em>2020.09.18 17:29</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','alle****', 'xdeQdzxXnSb6KaNf46Wl14zOt61MS3vj8ukyuFym8FA=', '애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장인물들의 노래가 없었던 것도 의아함. ', '17146549', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																디즈니..넘 실망....어떻게 그럴수있니
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143657, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>토이스토리(gpff****)</span>
# </a>
# </em>
# <em>2020.09.17 13:15</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','gpff****', 'URZd73KZKH4uXJYvL9OzNMUUDprapk62ZlBZxfEV2gQ=', '디즈니..넘 실망....어떻게 그럴수있니 ', '17143657', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																개봉하기전에 이미 봤다...ㅋㅋㅋㅋ견자단하고 이연걸 아깝다... 여기 왜 출연했어..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143509, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>므두셀라(hone****)</span>
# </a>
# </em>
# <em>2020.09.17 11:27</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','hone****', 'fm6oo1zRnjWcRpm1pH2igrxSW4hfSvgtW2vdAL+3PxU=', '개봉하기전에 이미 봤다...ㅋㅋㅋㅋ견자단하고 이연걸 아깝다... 여기 왜 출연했어.. ', '17143509', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																돈으로 헐리우드를 샀지만 관객마음은 못사지
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143592, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>ys(cysp****)</span>
# </a>
# </em>
# <em>2020.09.17 12:30</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','cysp****', 'y0yEb1PWwjudR1kUrRPoZS6lA7ttuzIjf1GyfqX+tqU=', '돈으로 헐리우드를 샀지만 관객마음은 못사지 ', '17143592', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																내 어린시절 뮬란을 이렇게 망치지마
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143801, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>현욱(unti****)</span>
# </a>
# </em>
# <em>2020.09.17 14:31</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','unti****', 'MRiScv8QprhiB3k1aPH6lHfIxkX8SOUiJKK+STNaEZ0=', '내 어린시절 뮬란을 이렇게 망치지마 ', '17143801', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																영화에 짜장이 묻으면 이 꼴 나는구나 ㅋ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143417, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>반찬우(banc****)</span>
# </a>
# </em>
# <em>2020.09.17 10:09</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','banc****', 'A7PYKKEhV2v7woMVN4RqqsOxFCgECtyYSxk5wRiPW1M=', '영화에 짜장이 묻으면 이 꼴 나는구나 ㅋ ', '17143417', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																이번만큼은 동의 합니다. 찌꺼기라는 평론가의 평점을..
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143726, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>올마이티히터(stap****)</span>
# </a>
# </em>
# <em>2020.09.17 13:55</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','stap****', 'mWhYWFYNiD194Ub8AiZc2b+qBy9UmQXz+y5+TRdDMOQ=', '이번만큼은 동의 합니다. 찌꺼기라는 평론가의 평점을.. ', '17143726', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span class="text_spo _text_spo" id="_text_spo_8">스포일러가 포함된 감상평입니다. <a class="btn_more" href="javascript:void(0);" onclick="showMovieReview('8');" role="button">감상평 보기</a></span>
# <span id="_filtered_ment_8" style="display:none;">
#
#
#
# 																음.... 알라딘은 예술성이 돋보였지만 뮬란은 ost도 없도 그냥 애니 줄거리만을 따라가기만 한 느낌 이에요... 감동도 예술성도 돋보이지 않고 밋밋해 실망스럽습니다
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17147442, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>구예은(sjo5****)</span>
# </a>
# </em>
# <em>2020.09.19 00:51</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','sjo5****', 'TuVsCq3NWDe+P8rSJDTET4Vv0VMN7aD5IQSJIzOqeXk=', '음.... 알라딘은 예술성이 돋보였지만 뮬란은 ost도 없도 그냥 애니 줄거리만을 따라가기만 한 느낌 이에요... 감동도 예술성도 돋보이지 않고 밋밋해 실망스럽습니다 ', '17147442', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="score_reple">
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																중국이 싫다고 1점 주지는 맙시다. 저는 이 영화가 싫어서 1점 줍니다.
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17143575, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>포지트론(inhy****)</span>
# </a>
# </em>
# <em>2020.09.17 12:24</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','inhy****', 'aHJmZghelfrJi625/28/Ozro+mJYsBLVArvr0J0vOYs=', '중국이 싫다고 1점 주지는 맙시다. 저는 이 영화가 싫어서 1점 줍니다. ', '17143575', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>

# %%
# find 함수를 한번 더 활용하여 <div> 태그 하위태그 중 <p> 태그만 골라 가져옵니다.
# class 속성이 없는 경우 입력하지 않아도 됩니다.
for comment in comment_list:
    print(comment.find("p"))
# Out:
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
# <span class="_unfold_ment" id="_unfold_ment0">
# <a data-src="일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈니 원작이 있으니 당연히 좋은건데.. 정말 이렇게 만들지 몰랐다... ㅡ_ㅡ 다들 무거운 진지충 연기... 초등학교 고학년 이상의 아이들은 몰라도 영유아나 저학년 아이들이 집중력있게 볼 수 있을만한 작품은 아닌듯... " href="javascript:void(0);" onclick="unfoldPointMent(this);">
# 																		일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈...
# 																	</a>
# </span>
# </span>
# </p>
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span class="text_spo _text_spo" id="_text_spo_1">스포일러가 포함된 감상평입니다. <a class="btn_more" href="javascript:void(0);" onclick="showMovieReview('1');" role="button">감상평 보기</a></span>
# <span id="_filtered_ment_1" style="display:none;">
# <span class="_unfold_ment" id="_unfold_ment1">
# <a data-src="애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장인물들의 노래가 없었던 것도 의아함. " href="javascript:void(0);" onclick="unfoldPointMent(this);">
# 																		애니메이션 ‘뮬란’ 실사화라고 하기에는 연출, 등장인물, 전개 모두 아쉬움.특히 마지막 검에 각인된 글자가 ‘효’...라는게..도대체 이 영화가 무엇을 보여주고 싶었는지 도저히 모르겠음.디즈니의 강점이자 특징인 등장...
# 																	</a>
# </span>
# </span>
# </p>
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_2">
#
#
#
# 																디즈니..넘 실망....어떻게 그럴수있니
#
#
#
# 													</span>
# </p>
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_3">
#
#
#
# 																개봉하기전에 이미 봤다...ㅋㅋㅋㅋ견자단하고 이연걸 아깝다... 여기 왜 출연했어..
#
#
#
# 													</span>
# </p>
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_4">
#
#
#
# 																돈으로 헐리우드를 샀지만 관객마음은 못사지
#
#
#
# 													</span>
# </p>
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_5">
#
#
#
# 																내 어린시절 뮬란을 이렇게 망치지마
#
#
#
# 													</span>
# </p>
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_6">
#
#
#
# 																영화에 짜장이 묻으면 이 꼴 나는구나 ㅋ
#
#
#
# 													</span>
# </p>
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_7">
#
#
#
# 																이번만큼은 동의 합니다. 찌꺼기라는 평론가의 평점을..
#
#
#
# 													</span>
# </p>
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span class="text_spo _text_spo" id="_text_spo_8">스포일러가 포함된 감상평입니다. <a class="btn_more" href="javascript:void(0);" onclick="showMovieReview('8');" role="button">감상평 보기</a></span>
# <span id="_filtered_ment_8" style="display:none;">
#
#
#
# 																음.... 알라딘은 예술성이 돋보였지만 뮬란은 ost도 없도 그냥 애니 줄거리만을 따라가기만 한 느낌 이에요... 감동도 예술성도 돋보이지 않고 밋밋해 실망스럽습니다
#
#
#
# 													</span>
# </p>
# <p>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_9">
#
#
#
# 																중국이 싫다고 1점 주지는 맙시다. 저는 이 영화가 싫어서 1점 줍니다.
#
#
#
# 													</span>
# </p>

# %%
# findAll 함수를 한번 더 활용하여 <p> 태그 하위태그 중 <span> 태그만 골라 가져옵니다.
for comment in comment_list:
    #print(comment.find("p").findAll("span"))
    span_tag_list = comment.find("p").findAll("span")#.findALL("span")
    if span_tag_list[0].text == "관람객":
        print(span_tag_list[1].text.strip())
    else:
        print(span_tag_list[0].text.strip())
# Out:
# 일단... 디지스타일의 애니메이션은 노래와 시대적 센스를 반영해서 재구성한 작품으로 호불호가 갈림에도 역시 디즈니!! 답다라는 평을 주는데... 이건.. 그냥 진지한 중국 무협영화를 영어로 보는 느낌? 스토리야 디즈...
# 스포일러가 포함된 감상평입니다. 감상평 보기
# 디즈니..넘 실망....어떻게 그럴수있니
# 개봉하기전에 이미 봤다...ㅋㅋㅋㅋ견자단하고 이연걸 아깝다... 여기 왜 출연했어..
# 돈으로 헐리우드를 샀지만 관객마음은 못사지
# 내 어린시절 뮬란을 이렇게 망치지마
# 영화에 짜장이 묻으면 이 꼴 나는구나 ㅋ
# 이번만큼은 동의 합니다. 찌꺼기라는 평론가의 평점을..
# 스포일러가 포함된 감상평입니다. 감상평 보기
# 중국이 싫다고 1점 주지는 맙시다. 저는 이 영화가 싫어서 1점 줍니다.

# %%
# 6. 가져온 데이터 정리해서 파일에 저장하기
# 새로운 파일을 생성해서 영화댓글을 저장합니다.
f = open("movie_comment.txt", "w", encoding="utf-8")
for comment in comment_list:
    #print(comment.find("p").findAll("span"))
    span_tag_list = comment.find("p").findAll("span")#.findALL("span")
    if span_tag_list[0].text == "관람객":
        f.write(span_tag_list[1].text.strip() + '\n')
    else:
        f.write(span_tag_list[0].text.strip() + '\n')
f.close()

# %%
# 파일에 저장된 실시간 검색어를 불러옵니다.
f = open("movie_comment.txt", encoding="utf-8")
for comment in f:
    print(comment.strip())
f.close()
# Out:
# 개인적으론 인셉션만큼 재밌다.내용은 전혀  파악불가인데 정말 끝내주는 액션과 시각효과에 반한 작품. 아카데미에서 시각부문수상이 유력해보인다. 놀란감독은 머릿속으로 상상하기도 힘든걸 영상으로 놀랍게 구현하는 재주를 지...
# 개봉일을 작년으로 연기시켜야 합니다.
# 인셉션 인터스텔라에 이은 대작
# 문과 관람 불가 등급...
# 스포일러가 포함된 감상평입니다. 감상평 보기
# 로버트 패틴슨 진짜 찐멋..
# 영화를 거꾸로 보면 이해할 수 있을까
# 스토리는 치밀했다. 그러나 전달방식은 불친절했다. 캐릭터들의 말로 빠르게 설명이 지나간다. 게다가 하이라이트에 가까워질수록 전개 속도가 더 빨라지는데 이때 관객이 함축적인(or구체적인 게 생략된) 설명들을 이해할 시...
# 스포일러가 포함된 감상평입니다. 감상평 보기
# 스포일러가 포함된 감상평입니다. 감상평 보기

# %% [markdown]
# ### Assignment 03-01. 네이버 영화댓글을 대량으로 가져오기
# > - 본 자료를 응용하여 네이버 영화댓글을 부가정보와 함께 대량으로 가져오는 코드를 작성합니다.
# > - 영화댓글 페이지의 100페이지 분량의 댓글을 수집합니다.
# > - 영화댓글 텍스트와 함께, 작성일자와 평점을 같이 가져옵니다.
# > - 영화댓글, 작성일자, 평점을 탭(\t) 단위로 구분하여 파일에 저장합니다.
#
# > HINT. 영화댓글 URL 맨 뒤의 숫자는 페이지 번호를 의미합니다. ("&page=1")
#
# ---
